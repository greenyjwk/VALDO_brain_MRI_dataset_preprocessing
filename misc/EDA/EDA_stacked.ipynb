# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
uid = 234
slice = 98

# %%
root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_stacked"
file_path = f"{root_path}/sub-{uid}/sub-{uid}.nii.gz"
img = nib.load(file_path)
img = img.get_fdata()

# %%
plt.figure(figsize=(10, 10))


plt.subplot(1,3,1)
plt.imshow(np.rot90(img[:, :, slice, 0]), cmap='gray')

plt.subplot(1,3,2)
plt.imshow(np.rot90(img[:, :, slice, 1]), cmap='gray')

plt.subplot(1,3,3)
plt.imshow(np.rot90(img[:, :, slice, 2]), cmap='gray')
