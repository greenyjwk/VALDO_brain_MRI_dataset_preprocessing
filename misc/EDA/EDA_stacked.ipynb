# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
uid = 234
slice = 98

# %%
file_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_stacked/sub-{uid}/sub-{uid}.nii.gz"
img = nib.load(file_path)
img = img.get_fdata()

# %%
plt.figure(figsize=(10, 10))


plt.subplot(1,3,1)
plt.imshow(np.rot90(img[:, :, slice, 0]), cmap='gray')

plt.subplot(1,3,2)
plt.imshow(np.rot90(img[:, :, slice, 1]), cmap='gray')

plt.subplot(1,3,3)
plt.imshow(np.rot90(img[:, :, slice, 2]), cmap='gray')
