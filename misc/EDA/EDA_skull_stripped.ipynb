# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
uid = 108
slice = 15

# %%
T1 = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-{uid}/T1_sub-{uid}.nii.gz")
T1 = T1.get_fdata()

T2 = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-{uid}/T1_sub-{uid}.nii.gz")
T2 = T2.get_fdata()

T2S = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-{uid}/T2S_sub-{uid}.nii.gz")
T2S = T2S.get_fdata()

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.imshow(T1[:,:,slice].T, cmap='gray', origin='lower')
plt.title('T1')

plt.subplot(132)
plt.imshow(T2[:,:,slice].T, cmap='gray', origin='lower')
plt.title('T2')

plt.subplot(133)
plt.imshow(T2S[:,:,slice].T, cmap='gray', origin='lower')
plt.title('T2S')
# Out:
# Text(0.5, 1.0, 'T2S')
