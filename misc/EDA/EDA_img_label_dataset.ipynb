# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
from pathlib import Path

# %%
root_path = "/mnt/storage/ji/TEMP2/images/"
task = "train"
# /mnt/storage/ji/TEMP2/images/train/sub-233_slice_041.png
# root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_original_ESRGAN"
# task = "train_cmb_slice_only"

# root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_ESRGAN_T2S_only"
# task = "val"

# %% [markdown]
# ### Count the number of patients

# %%
patient_set = set()
images_path = os.path.join(root_path,'images', 'val')
for file in os.listdir(images_path):
    patient_uid = file.split('_')[0]
    if patient_uid not in patient_set:
        patient_set.add(patient_uid)
# print(patient_set)
len(patient_set)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 patient_set = set()
#       2 images_path = os.path.join(root_path,'images', 'val')
# ----> 3 for file in os.listdir(images_path):
#       4     patient_uid = file.split('_')[0]
#       5     if patient_uid not in patient_set:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/storage/ji/TEMP2/images/images/val'

# %% [markdown]
# ### Dataset Visualization

# %%
# Image path
# /images/train/sub-101_slice_009.png
# /sub-233_slice_041.png
img_num = "233"
slice_num = "041"

# %% [markdown]
# ### Mask

# %%
mask_path = f"{root_path}/masks/{task}/sub-{img_num}_slice_{slice_num}.png"
mask = Image.open(mask_path)
mask = np.array(mask)
print(np.sum(mask==255))
plt.imshow(mask, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 mask_path = f"{root_path}/masks/{task}/sub-{img_num}_slice_{slice_num}.png"
# ----> 2 mask = Image.open(mask_path)
#       3 mask = np.array(mask)
#       4 print(np.sum(mask==255))
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/PIL/Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/storage/ji/TEMP2/masks/train/sub-233_slice_041.png'

# %%
with open("raw_output.txt", "w") as f:
    for row in mask:
        f.write(" | ".join(f"{num:6.2f}" for num in row) + "\n")

# %%
# np.set_printoptions(threshold=np.inf)
# print(mask)

# %% [markdown]
# ### Fixed Size Ground Truth Box

# %%
def extract_patch(channel, center_x, center_y, patch_size):
    """
    Extract a fixed-size patch centered on the given coordinates
    """
    height, width = channel.shape
    half_size = patch_size // 2
    
    # Calculate patch boundaries
    x_min = int(center_x - half_size)
    y_min = int(center_y - half_size)
    x_max = int(center_x + half_size)
    y_max = int(center_y + half_size)
    
    # Handle edge cases
    if x_min < 0:
        x_max -= x_min  # Shift patch right
        x_min = 0
    if y_min < 0:
        y_max -= y_min  # Shift patch down
        y_min = 0
    if x_max > width:
        x_min -= (x_max - width)  # Shift patch left
        x_max = width
    if y_max > height:
        y_min -= (y_max - height)  # Shift patch up
        y_max = height
    
    return channel[y_min:y_max, x_min:x_max]

def plot_yolo_boxes_with_channel_patches(image_path, bboxes):
    """
    Plot original channels and their 16x16 patches without overlap
    """
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"The image file does not exist: {image_path}")
    
    try:
        image = Image.open(image_path)
        image = np.array(image)
    except Exception as e:
        raise IOError(f"Error reading the image: {e}")
    
    if len(image.shape) == 2:
        image = np.stack((image,) * 3, axis=-1)
    height, width = image.shape[:2]
    n_boxes = len(bboxes)
    
    if n_boxes == 0:
        print("No bounding boxes found in the image.")
        return
        
    # Create figure with original image row plus one row per bbox
    fig = plt.figure(figsize=(15, 4 * (n_boxes + 1)))

    # Create GridSpec with n_boxes + 1 rows (1 for original images, rest for patches)
    gs = plt.GridSpec(n_boxes + 1, 3, figure=fig, hspace=0.4)

    # Channel names
    channel_names = ['T1', 'T2', 'T2S']

    # Plot each channel
    for channel_idx, channel_name in enumerate(channel_names):
        # Extract channel
        channel = image[:, :, channel_idx]

        # Plot full image in top row
        ax = fig.add_subplot(gs[0, channel_idx])
        # im = ax.imshow(channel, cmap='gray', vmin=0, vmax=255)
        im = ax.imshow(channel, cmap='gray')
        ax.set_title(f'{channel_name}')
        plt.colorbar(im, ax=ax, label='Intensity')
        
        # Draw all bounding boxes on original image
        for bbox in bboxes:
            class_id, x_center, y_center, gt_width, gt_height = bbox
            center_x = int(x_center * width)
            center_y = int(y_center * height)
            
            patch_size = gt_width * width
            
            # Draw fixed-size box
            half_size = patch_size // 2
            x_min = center_x - half_size
            y_min = center_y - half_size
            
            rect = plt.Rectangle((x_min, y_min), patch_size, patch_size,
                               linewidth=0.3, edgecolor='red', facecolor='none')
            ax.add_patch(rect)
        
        # Plot patches
        for box_idx, bbox in enumerate(bboxes):
            _, x_center, y_center, gt_width, gt_height = bbox
            center_x = int(x_center * width)
            center_y = int(y_center * height)
            
            # Extract patch
            patch_size = gt_width * width
            patch = extract_patch(channel, center_x, center_y, patch_size)
            # Create subplot for patch in its own row
            ax_patch = fig.add_subplot(gs[box_idx + 1, channel_idx])
            # im_patch = ax_patch.imshow(patch, cmap='gray', vmin=0, vmax=255)
            im_patch = ax_patch.imshow(patch, cmap='gray')
            ax_patch.set_title(f'{channel_name} Patch {box_idx + 1}')
            plt.colorbar(im_patch, ax=ax_patch, label='Intensity')
            ax_patch.axis('on')
    
    plt.suptitle('Ground Truth', fontsize=16, y=0.95)
    plt.tight_layout()
    plt.show()

def visualize_image_channels_and_patches(root_path, img_num, slice_num):
    """
    Visualize MRI channels and their patches with fixed-size boxes
    """
    label_path = f"{root_path}/labels/{task}/sub-{img_num}_slice_{slice_num}.txt"
    image_path = label_path.replace("labels", "images").replace("txt", "png")

    plot_original_image(image_path)
    
    try:
        with open(label_path, 'r') as txt_file:
            bboxes = [list(map(float, line.split())) for line in txt_file.readlines()]
        
        plot_yolo_boxes_with_channel_patches(image_path, bboxes)
        
    except Exception as e:
        print(f"An error occurred: {e}")
        try:
            with Image.open(image_path) as img:
                print(f"Image format: {img.format}")
                print(f"Image size: {img.size}")
                print(f"Image mode: {img.mode}")
        except Exception as e:
            print(f"Could not open the image for additional information: {e}")
            
def plot_original_image(img_path):    
    img = Image.open(img_path)
    img = np.array(img)
    
    print(img.shape)
    plt.figure(figsize=(10, 10))

    plt.subplot(1,3,1)
    plt.imshow(img[:,:,0], cmap='gray')
    plt.title('T1 Original Image')

    plt.subplot(1,3,2)
    plt.imshow(img[:,:,1], cmap='gray')
    plt.title('T2 Original Image')

    plt.subplot(1,3,3)
    plt.imshow(img[:,:,2], cmap='gray')
    plt.title('T2S Original Image')

# %%
visualize_image_channels_and_patches(root_path, img_num, slice_num)
# Out:
# (512, 512)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 visualize_image_channels_and_patches(root_path, img_num, slice_num)
#
# Cell In[42], line 118, in visualize_image_channels_and_patches(root_path, img_num, slice_num)
#     115 label_path = f"{root_path}/labels/{task}/sub-{img_num}_slice_{slice_num}.txt"
#     116 image_path = label_path.replace("labels", "images").replace("txt", "png")
# --> 118 plot_original_image(image_path)
#     120 try:
#     121     with open(label_path, 'r') as txt_file:
#
# Cell In[42], line 144, in plot_original_image(img_path)
#     141 plt.figure(figsize=(10, 10))
#     143 plt.subplot(1,3,1)
# --> 144 plt.imshow(img[:,:,0], cmap='gray')
#     145 plt.title('T1 Original Image')
#     147 plt.subplot(1,3,2)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
def find_nonempty_text_files(directory):
    nonempty_files = []
    dir_path = Path(directory)
    for txt_file in dir_path.glob("*.txt"):
        if txt_file.stat().st_size > 0:
            with open(txt_file, 'r') as f:
                content = f.read().strip()
                if content:  # Check if there's actual content after stripping whitespace
                    nonempty_files.append(txt_file.name)  
    return sorted(nonempty_files)  # Sort alphabetically

# task = "val"
directory = f"{root_path}/labels/{task}"  # Replace with your folder path
nonempty_files = find_nonempty_text_files(directory)

count = 0
print(f"Found {len(nonempty_files)} non-empty text files:")
for filename in nonempty_files:
    count += 1
    print(f"- {filename}")
print(count)
# Out:
# Found 282 non-empty text files:
# - sub-101_slice_008.txt
# - sub-101_slice_009.txt
# - sub-101_slice_011.txt
# - sub-101_slice_012.txt
# - sub-101_slice_015.txt
# - sub-101_slice_016.txt
# - sub-101_slice_017.txt
# - sub-101_slice_027.txt
# - sub-102_slice_017.txt
# - sub-106_slice_011.txt
# - sub-106_slice_013.txt
# - sub-106_slice_014.txt
# - sub-107_slice_013.txt
# - sub-107_slice_023.txt
# - sub-108_slice_015.txt
# - sub-108_slice_016.txt
# - sub-108_slice_017.txt
# - sub-108_slice_025.txt
# - sub-207_slice_062.txt
# - sub-207_slice_063.txt
# - sub-207_slice_064.txt
# - sub-207_slice_065.txt
# - sub-207_slice_066.txt
# - sub-207_slice_090.txt
# - sub-207_slice_091.txt
# - sub-207_slice_092.txt
# - sub-207_slice_093.txt
# - sub-207_slice_102.txt
# - sub-207_slice_103.txt
# - sub-207_slice_104.txt
# - sub-207_slice_105.txt
# - sub-207_slice_106.txt
# - sub-207_slice_107.txt
# - sub-207_slice_108.txt
# - sub-207_slice_109.txt
# - sub-207_slice_130.txt
# - sub-208_slice_112.txt
# - sub-208_slice_113.txt
# - sub-208_slice_114.txt
# - sub-208_slice_115.txt
# - sub-212_slice_121.txt
# - sub-212_slice_122.txt
# - sub-213_slice_093.txt
# - sub-215_slice_093.txt
# - sub-215_slice_094.txt
# - sub-215_slice_095.txt
# - sub-216_slice_046.txt
# - sub-216_slice_047.txt
# - sub-216_slice_048.txt
# - sub-216_slice_049.txt
# - sub-216_slice_050.txt
# - sub-216_slice_051.txt
# - sub-216_slice_052.txt
# - sub-216_slice_056.txt
# - sub-216_slice_057.txt
# - sub-216_slice_058.txt
# - sub-216_slice_059.txt
# - sub-216_slice_060.txt
# - sub-216_slice_069.txt
# - sub-216_slice_070.txt
# - sub-216_slice_071.txt
# - sub-216_slice_072.txt
# - sub-216_slice_089.txt
# - sub-216_slice_090.txt
# - sub-216_slice_091.txt
# - sub-216_slice_092.txt
# - sub-216_slice_093.txt
# - sub-216_slice_098.txt
# - sub-216_slice_099.txt
# - sub-216_slice_100.txt
# - sub-216_slice_101.txt
# - sub-216_slice_102.txt
# - sub-216_slice_103.txt
# - sub-216_slice_104.txt
# - sub-216_slice_105.txt
# - sub-216_slice_106.txt
# - sub-216_slice_107.txt
# - sub-216_slice_108.txt
# - sub-216_slice_109.txt
# - sub-216_slice_110.txt
# - sub-216_slice_111.txt
# - sub-216_slice_112.txt
# - sub-216_slice_113.txt
# - sub-216_slice_114.txt
# - sub-216_slice_115.txt
# - sub-216_slice_116.txt
# - sub-216_slice_128.txt
# - sub-216_slice_129.txt
# - sub-216_slice_130.txt
# - sub-216_slice_131.txt
# - sub-216_slice_132.txt
# - sub-216_slice_133.txt
# - sub-218_slice_054.txt
# - sub-218_slice_055.txt
# - sub-218_slice_056.txt
# - sub-218_slice_057.txt
# - sub-218_slice_058.txt
# - sub-218_slice_059.txt
# - sub-218_slice_060.txt
# - sub-218_slice_061.txt
# - sub-218_slice_062.txt
# - sub-218_slice_078.txt
# - sub-218_slice_079.txt
# - sub-218_slice_080.txt
# - sub-218_slice_081.txt
# - sub-218_slice_089.txt
# - sub-218_slice_090.txt
# - sub-218_slice_091.txt
# - sub-218_slice_092.txt
# - sub-218_slice_093.txt
# - sub-218_slice_094.txt
# - sub-218_slice_095.txt
# - sub-218_slice_096.txt
# - sub-218_slice_097.txt
# - sub-218_slice_100.txt
# - sub-218_slice_101.txt
# - sub-218_slice_102.txt
# - sub-218_slice_103.txt
# - sub-218_slice_104.txt
# - sub-218_slice_105.txt
# - sub-218_slice_106.txt
# - sub-218_slice_107.txt
# - sub-218_slice_108.txt
# - sub-218_slice_109.txt
# - sub-218_slice_111.txt
# - sub-218_slice_113.txt
# - sub-218_slice_116.txt
# - sub-218_slice_117.txt
# - sub-218_slice_118.txt
# - sub-218_slice_119.txt
# - sub-218_slice_120.txt
# - sub-218_slice_121.txt
# - sub-218_slice_129.txt
# - sub-218_slice_130.txt
# - sub-218_slice_131.txt
# - sub-218_slice_132.txt
# - sub-218_slice_133.txt
# - sub-218_slice_134.txt
# - sub-218_slice_136.txt
# - sub-218_slice_140.txt
# - sub-218_slice_141.txt
# - sub-218_slice_142.txt
# - sub-218_slice_148.txt
# - sub-218_slice_150.txt
# - sub-218_slice_152.txt
# - sub-218_slice_154.txt
# - sub-218_slice_155.txt
# - sub-221_slice_076.txt
# - sub-221_slice_077.txt
# - sub-221_slice_078.txt
# - sub-221_slice_082.txt
# - sub-221_slice_083.txt
# - sub-221_slice_084.txt
# - sub-221_slice_085.txt
# - sub-221_slice_096.txt
# - sub-221_slice_097.txt
# - sub-221_slice_098.txt
# - sub-221_slice_107.txt
# - sub-221_slice_108.txt
# - sub-221_slice_109.txt
# - sub-221_slice_110.txt
# - sub-221_slice_111.txt
# - sub-221_slice_112.txt
# - sub-221_slice_113.txt
# - sub-221_slice_127.txt
# - sub-221_slice_128.txt
# - sub-221_slice_129.txt
# - sub-221_slice_130.txt
# - sub-221_slice_131.txt
# - sub-221_slice_132.txt
# - sub-221_slice_133.txt
# - sub-221_slice_137.txt
# - sub-221_slice_138.txt
# - sub-221_slice_139.txt
# - sub-221_slice_140.txt
# - sub-221_slice_141.txt
# - sub-221_slice_142.txt
# - sub-221_slice_143.txt
# - sub-221_slice_144.txt
# - sub-222_slice_065.txt
# - sub-222_slice_066.txt
# - sub-222_slice_067.txt
# - sub-222_slice_068.txt
# - sub-222_slice_116.txt
# - sub-222_slice_117.txt
# - sub-222_slice_118.txt
# - sub-222_slice_119.txt
# - sub-222_slice_134.txt
# - sub-222_slice_135.txt
# - sub-222_slice_136.txt
# - sub-222_slice_137.txt
# - sub-222_slice_138.txt
# - sub-222_slice_143.txt
# - sub-222_slice_144.txt
# - sub-222_slice_145.txt
# - sub-222_slice_146.txt
# - sub-222_slice_147.txt
# - sub-222_slice_148.txt
# - sub-222_slice_149.txt
# - sub-222_slice_150.txt
# - sub-222_slice_154.txt
# - sub-222_slice_155.txt
# - sub-222_slice_156.txt
# - sub-222_slice_162.txt
# - sub-222_slice_163.txt
# - sub-222_slice_164.txt
# - sub-222_slice_166.txt
# - sub-222_slice_167.txt
# - sub-222_slice_168.txt
# - sub-222_slice_169.txt
# - sub-223_slice_029.txt
# - sub-228_slice_046.txt
# - sub-228_slice_047.txt
# - sub-228_slice_048.txt
# - sub-228_slice_049.txt
# - sub-228_slice_050.txt
# - sub-228_slice_051.txt
# - sub-228_slice_052.txt
# - sub-228_slice_053.txt
# - sub-228_slice_054.txt
# - sub-228_slice_055.txt
# - sub-228_slice_089.txt
# - sub-228_slice_090.txt
# - sub-228_slice_091.txt
# - sub-228_slice_100.txt
# - sub-228_slice_101.txt
# - sub-228_slice_102.txt
# - sub-228_slice_103.txt
# - sub-228_slice_104.txt
# - sub-228_slice_105.txt
# - sub-228_slice_106.txt
# - sub-228_slice_107.txt
# - sub-228_slice_108.txt
# - sub-228_slice_109.txt
# - sub-228_slice_110.txt
# - sub-229_slice_126.txt
# - sub-234_slice_083.txt
# - sub-234_slice_084.txt
# - sub-234_slice_098.txt
# - sub-234_slice_099.txt
# - sub-234_slice_100.txt
# - sub-234_slice_101.txt
# - sub-234_slice_102.txt
# - sub-301_slice_035.txt
# - sub-302_slice_022.txt
# - sub-302_slice_023.txt
# - sub-302_slice_024.txt
# - sub-303_slice_025.txt
# - sub-304_slice_020.txt
# - sub-305_slice_003.txt
# - sub-305_slice_012.txt
# - sub-305_slice_013.txt
# - sub-306_slice_033.txt
# - sub-306_slice_034.txt
# - sub-307_slice_020.txt
# - sub-309_slice_016.txt
# - sub-310_slice_031.txt
# - sub-311_slice_013.txt
# - sub-311_slice_014.txt
# - sub-312_slice_023.txt
# - sub-312_slice_024.txt
# - sub-313_slice_009.txt
# - sub-314_slice_022.txt
# - sub-315_slice_025.txt
# - sub-316_slice_015.txt
# - sub-316_slice_019.txt
# - sub-318_slice_016.txt
# - sub-319_slice_002.txt
# - sub-320_slice_013.txt
# - sub-320_slice_018.txt
# - sub-322_slice_023.txt
# - sub-322_slice_024.txt
# - sub-322_slice_025.txt
# - sub-323_slice_021.txt
# - sub-324_slice_013.txt
# - sub-324_slice_014.txt
# - sub-325_slice_018.txt
# - sub-325_slice_023.txt
# - sub-325_slice_025.txt
# - sub-325_slice_026.txt
# - sub-326_slice_024.txt
# - sub-327_slice_020.txt
# 282
