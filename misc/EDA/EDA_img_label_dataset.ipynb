# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path

# %%
# root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_GAN_cmbOnly"
root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_GAN_2class_csf"

task = "train"
img_num = "101"
slice_num = "017"

# %% [markdown]
# ### Count the number of patients

# %%
patient_set = set()
images_path = os.path.join(root_path,'images', 'val')
for file in os.listdir(images_path):
    patient_uid = file.split('_')[0]
    if patient_uid not in patient_set:
        patient_set.add(patient_uid)
# print(patient_set)
len(patient_set)
# Out:
# 12

# %% [markdown]
# ### Mask

# %%
if task == 'train':
    mask_path = f"{root_path}/masks/{task}/sub-{img_num}_slice_{slice_num}.png"
    mask = Image.open(mask_path)
    mask = np.array(mask)
    print(np.sum(mask==255))
    plt.imshow(mask, cmap='gray')
# Out:
# 80

# %%
if task == 'train':

    with open("raw_output.txt", "w") as f:
        for row in mask:
            f.write(" | ".join(f"{num:6.2f}" for num in row) + "\n")

# %% [markdown]
# ### Fixed Size Ground Truth Box

# %%
def plot_pixel_distribution(image_path):
    """
    Plot the pixel intensity distribution of the third channel (T2S) of the image.
    """
    # Load the image
    img = Image.open(image_path)
    img = np.array(img)

    # Check if the image has at least 3 channels
    if img.shape[-1] < 3:
        raise ValueError("The image does not have at least 3 channels.")

    # Extract the third channel (T2S)
    t2s_channel = img[:, :, 2]

    # Plot the histogram
    plt.figure(figsize=(6, 3))  # Compact figure size
    plt.hist(t2s_channel.ravel(), bins=256, range=(0, 255), color='blue', alpha=0.7)
    plt.title("Pixel Intensity Distribution of T2S Channel", fontsize=10)
    plt.xlabel("Pixel Intensity (0-255)", fontsize=8)
    plt.ylabel("Frequency", fontsize=8)
    plt.ylim(0, 100000)  # Limit y-axis to 300
    plt.grid(False, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()



def extract_patch(channel, center_x, center_y, patch_size):
    """
    Extract a fixed-size patch centered on the given coordinates
    """
    height, width = channel.shape
    half_size = patch_size // 2
    
    # Calculate patch boundaries
    x_min = int(center_x - half_size)
    y_min = int(center_y - half_size)
    x_max = int(center_x + half_size)
    y_max = int(center_y + half_size)
    
    # Handle edge cases
    if x_min < 0:
        x_max -= x_min  # Shift patch right
        x_min = 0
    if y_min < 0:
        y_max -= y_min  # Shift patch down
        y_min = 0
    if x_max > width:
        x_min -= (x_max - width)  # Shift patch left
        x_max = width
    if y_max > height:
        y_min -= (y_max - height)  # Shift patch up
        y_max = height
    
    return channel[y_min:y_max, x_min:x_max]

def plot_yolo_boxes_with_channel_patches(image_path, bboxes):
    """
    Plot original channels and their 16x16 patches without overlap
    """
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"The image file does not exist: {image_path}")
    
    try:
        image = Image.open(image_path)
        image = np.array(image)
    except Exception as e:
        raise IOError(f"Error reading the image: {e}")
    
    if len(image.shape) == 2:
        image = np.stack((image,) * 3, axis=-1)
    height, width = image.shape[:2]
    n_boxes = len(bboxes)
    
    if n_boxes == 0:
        print("No bounding boxes found in the image.")
        return
        
    # Create figure with original image row plus one row per bbox
    fig = plt.figure(figsize=(15, 4 * (n_boxes + 1)))

    # Create GridSpec with n_boxes + 1 rows (1 for original images, rest for patches)
    gs = plt.GridSpec(n_boxes + 1, 3, figure=fig, hspace=0.4)

    # Channel names
    channel_names = ['T1', 'T2', 'T2S']

    # Plot each channel
    for channel_idx, channel_name in enumerate(channel_names):
        # Extract channel
        channel = image[:, :, channel_idx]

        # Plot full image in top row
        ax = fig.add_subplot(gs[0, channel_idx])
        # im = ax.imshow(channel, cmap='gray', vmin=0, vmax=255)
        im = ax.imshow(channel, cmap='gray')
        ax.axis('off')  # Hide axis ticks and numbers

        
        # ax.set_title(f'{channel_name}')
        # plt.colorbar(im, ax=ax, label='Intensity')
        
        # Draw all bounding boxes on original image
        for bbox in bboxes:
            class_id, x_center, y_center, gt_width, gt_height = bbox
            center_x = int(x_center * width)
            center_y = int(y_center * height)
            
            patch_size = gt_width * width
            
            # Draw fixed-size box
            half_size = patch_size // 2
            x_min = center_x - half_size
            y_min = center_y - half_size
            
            if class_id == 0:
                # Draw box for class 0
                rect = plt.Rectangle((x_min, y_min), patch_size, patch_size,
                                     linewidth=0.5, edgecolor='blue', facecolor='none')
            elif class_id == 1:
                rect = plt.Rectangle((x_min, y_min), patch_size, patch_size,
                                linewidth=0.3, edgecolor='red', facecolor='none')
            ax.add_patch(rect)
        
        # Plot patches
        for box_idx, bbox in enumerate(bboxes):
            _, x_center, y_center, gt_width, gt_height = bbox
            center_x = int(x_center * width)
            center_y = int(y_center * height)
            
            # Extract patch
            patch_size = gt_width * width
            patch = extract_patch(channel, center_x, center_y, patch_size)
            # Create subplot for patch in its own row
            ax_patch = fig.add_subplot(gs[box_idx + 1, channel_idx])
            # im_patch = ax_patch.imshow(patch, cmap='gray', vmin=0, vmax=255)
            im_patch = ax_patch.imshow(patch, cmap='gray')
            # ax_patch.set_title(f'{channel_name} Patch {box_idx + 1}')
            # plt.colorbar(im_patch, ax=ax_patch, label='Intensity')
            ax_patch.axis('off')
    
    # plt.suptitle('Ground Truth', fontsize=16, y=0.95)
    plt.tight_layout()
    plt.show()

def visualize_image_channels_and_patches(root_path, img_num, slice_num):
    """
    Visualize MRI channels and their patches with fixed-size boxes
    """
    label_path = f"{root_path}/labels/{task}/sub-{img_num}_slice_{slice_num}.txt"
    image_path = label_path.replace("labels", "images").replace("txt", "png")

    # plot_original_image(image_path)
    # plot_pixel_distribution(image_path)
    
    try:
        with open(label_path, 'r') as txt_file:
            bboxes = [list(map(float, line.split())) for line in txt_file.readlines()]
        
        plot_yolo_boxes_with_channel_patches(image_path, bboxes)
        
    except Exception as e:
        print(f"An error occurred: {e}")
        try:
            with Image.open(image_path) as img:
                print(f"Image format: {img.format}")
                print(f"Image size: {img.size}")
                print(f"Image mode: {img.mode}")
        except Exception as e:
            print(f"Could not open the image for additional information: {e}")
            
def plot_original_image(img_path):    
    img = Image.open(img_path)
    img = np.array(img)
    
    print(img.shape)
    plt.figure(figsize=(10, 10))

    plt.subplot(1,3,1)
    plt.imshow(img[:,:,0], cmap='gray')
    
    plt.subplot(1,3,2)
    plt.imshow(img[:,:,1], cmap='gray')
    
    plt.subplot(1,3,3)
    plt.imshow(img[:,:,2], cmap='gray')

# %%
visualize_image_channels_and_patches(root_path, img_num, slice_num)
# Out:
# An error occurred: Image size of 1500x80000 pixels is too large. It must be less than 2^16 in each direction.
# Image format: PNG
# Image size: (2048, 2048)
# Image mode: RGB
# Error in callback <function _draw_all_if_interactive at 0x7fa3cb7d6ca0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 1500x80000 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backend_bases.py:2167, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2162 layout_engine = self.figure.get_layout_engine()
#    2163 if layout_engine is not None or bbox_inches == "tight":
#    2164     # we need to trigger a draw before printing to make sure
#    2165     # CL works.  "tight" also needs a draw to get the right
#    2166     # locations:
# -> 2167     renderer = _get_renderer(
#    2168         self.figure,
#    2169         functools.partial(
#    2170             print_method, orientation=orientation)
#    2171     )
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backend_bases.py:1588, in _get_renderer(figure, print_method)
#    1585     print_method = stack.enter_context(
#    1586         figure.canvas._switch_canvas_and_return_print_method(fmt))
#    1587 try:
# -> 1588     print_method(io.BytesIO())
#    1589 except Done as exc:
#    1590     renderer, = exc.args
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 1500x80000 pixels is too large. It must be less than 2^16 in each direction.

# %%
def find_nonempty_text_files(directory):
    nonempty_files = []
    dir_path = Path(directory)
    for txt_file in dir_path.glob("*.txt"):
        if txt_file.stat().st_size > 0:
            with open(txt_file, 'r') as f:
                content = f.read().strip()
                if content:  # Check if there's actual content after stripping whitespace
                    nonempty_files.append(txt_file.name)  
    return sorted(nonempty_files)  # Sort alphabetically

# task = "val"
directory = f"{root_path}/labels/{task}"  # Replace with your folder path
nonempty_files = find_nonempty_text_files(directory)

count = 0
print(f"Found {len(nonempty_files)} non-empty text files:")
for filename in nonempty_files:
    count += 1
    print(f"- {filename}")
print(count)
# Out:
# Found 717 non-empty text files:
# - sub-101_slice_004.txt
# - sub-101_slice_008.txt
# - sub-101_slice_009.txt
# - sub-101_slice_011.txt
# - sub-101_slice_012.txt
# - sub-101_slice_015.txt
# - sub-101_slice_016.txt
# - sub-101_slice_017.txt
# - sub-101_slice_027.txt
# - sub-101_slice_033.txt
# - sub-207_slice_130.txt
# - sub-207_slice_136.txt
# - sub-207_slice_147.txt
# - sub-207_slice_149.txt
# - sub-208_slice_019.txt
# - sub-208_slice_030.txt
# - sub-208_slice_031.txt
# - sub-208_slice_063.txt
# - sub-208_slice_064.txt
# - sub-208_slice_092.txt
# - sub-208_slice_103.txt
# - sub-208_slice_109.txt
# - sub-208_slice_111.txt
# - sub-208_slice_112.txt
# - sub-208_slice_113.txt
# - sub-208_slice_114.txt
# - sub-208_slice_115.txt
# - sub-208_slice_130.txt
# - sub-208_slice_138.txt
# - sub-208_slice_158.txt
# - sub-208_slice_170.txt
# - sub-208_slice_172.txt
# - sub-208_slice_175.txt
# - sub-208_slice_182.txt
# - sub-209_slice_027.txt
# - sub-209_slice_029.txt
# - sub-209_slice_049.txt
# - sub-209_slice_059.txt
# - sub-209_slice_094.txt
# - sub-209_slice_102.txt
# - sub-209_slice_103.txt
# - sub-209_slice_104.txt
# - sub-209_slice_111.txt
# - sub-209_slice_132.txt
# - sub-209_slice_141.txt
# - sub-209_slice_154.txt
# - sub-209_slice_176.txt
# - sub-210_slice_008.txt
# - sub-210_slice_010.txt
# - sub-210_slice_039.txt
# - sub-210_slice_057.txt
# - sub-210_slice_080.txt
# - sub-210_slice_105.txt
# - sub-210_slice_108.txt
# - sub-210_slice_135.txt
# - sub-210_slice_138.txt
# - sub-210_slice_157.txt
# - sub-210_slice_160.txt
# - sub-210_slice_172.txt
# - sub-210_slice_180.txt
# - sub-211_slice_018.txt
# - sub-211_slice_023.txt
# - sub-211_slice_043.txt
# - sub-211_slice_048.txt
# - sub-211_slice_062.txt
# - sub-211_slice_063.txt
# - sub-211_slice_073.txt
# - sub-211_slice_079.txt
# - sub-211_slice_094.txt
# - sub-211_slice_127.txt
# - sub-211_slice_152.txt
# - sub-211_slice_160.txt
# - sub-212_slice_025.txt
# - sub-212_slice_059.txt
# - sub-212_slice_083.txt
# - sub-212_slice_117.txt
# - sub-212_slice_121.txt
# - sub-212_slice_122.txt
# - sub-212_slice_123.txt
# - sub-212_slice_131.txt
# - sub-212_slice_135.txt
# - sub-212_slice_140.txt
# - sub-212_slice_142.txt
# - sub-212_slice_146.txt
# - sub-212_slice_173.txt
# - sub-212_slice_188.txt
# - sub-213_slice_032.txt
# - sub-213_slice_054.txt
# - sub-213_slice_091.txt
# - sub-213_slice_092.txt
# - sub-213_slice_093.txt
# - sub-213_slice_110.txt
# - sub-213_slice_122.txt
# - sub-213_slice_129.txt
# - sub-213_slice_139.txt
# - sub-213_slice_158.txt
# - sub-213_slice_178.txt
# - sub-213_slice_179.txt
# - sub-213_slice_182.txt
# - sub-213_slice_183.txt
# - sub-214_slice_027.txt
# - sub-214_slice_041.txt
# - sub-214_slice_042.txt
# - sub-214_slice_065.txt
# - sub-214_slice_091.txt
# - sub-214_slice_095.txt
# - sub-214_slice_098.txt
# - sub-214_slice_115.txt
# - sub-214_slice_124.txt
# - sub-214_slice_165.txt
# - sub-214_slice_173.txt
# - sub-222_slice_045.txt
# - sub-222_slice_065.txt
# - sub-222_slice_066.txt
# - sub-222_slice_067.txt
# - sub-222_slice_068.txt
# - sub-222_slice_079.txt
# - sub-222_slice_081.txt
# - sub-222_slice_098.txt
# - sub-222_slice_102.txt
# - sub-222_slice_105.txt
# - sub-222_slice_107.txt
# - sub-222_slice_109.txt
# - sub-222_slice_116.txt
# - sub-222_slice_117.txt
# - sub-222_slice_118.txt
# - sub-222_slice_119.txt
# - sub-222_slice_132.txt
# - sub-222_slice_134.txt
# - sub-222_slice_135.txt
# - sub-222_slice_136.txt
# - sub-222_slice_137.txt
# - sub-222_slice_138.txt
# - sub-222_slice_143.txt
# - sub-222_slice_144.txt
# - sub-222_slice_145.txt
# - sub-222_slice_146.txt
# - sub-222_slice_147.txt
# - sub-222_slice_148.txt
# - sub-222_slice_149.txt
# - sub-222_slice_150.txt
# - sub-222_slice_153.txt
# - sub-222_slice_154.txt
# - sub-222_slice_155.txt
# - sub-222_slice_156.txt
# - sub-222_slice_161.txt
# - sub-222_slice_162.txt
# - sub-222_slice_163.txt
# - sub-222_slice_164.txt
# - sub-222_slice_166.txt
# - sub-222_slice_167.txt
# - sub-222_slice_168.txt
# - sub-222_slice_169.txt
# - sub-223_slice_009.txt
# - sub-223_slice_016.txt
# - sub-223_slice_024.txt
# - sub-223_slice_027.txt
# - sub-223_slice_028.txt
# - sub-223_slice_029.txt
# - sub-223_slice_030.txt
# - sub-223_slice_043.txt
# - sub-223_slice_055.txt
# - sub-223_slice_079.txt
# - sub-223_slice_093.txt
# - sub-223_slice_115.txt
# - sub-223_slice_118.txt
# - sub-223_slice_151.txt
# - sub-223_slice_167.txt
# - sub-224_slice_004.txt
# - sub-224_slice_008.txt
# - sub-224_slice_029.txt
# - sub-224_slice_032.txt
# - sub-224_slice_033.txt
# - sub-224_slice_048.txt
# - sub-224_slice_063.txt
# - sub-224_slice_071.txt
# - sub-224_slice_082.txt
# - sub-224_slice_126.txt
# - sub-224_slice_132.txt
# - sub-224_slice_146.txt
# - sub-224_slice_166.txt
# - sub-225_slice_011.txt
# - sub-225_slice_013.txt
# - sub-225_slice_019.txt
# - sub-225_slice_022.txt
# - sub-225_slice_023.txt
# - sub-225_slice_039.txt
# - sub-225_slice_042.txt
# - sub-225_slice_059.txt
# - sub-225_slice_069.txt
# - sub-225_slice_081.txt
# - sub-225_slice_083.txt
# - sub-225_slice_084.txt
# - sub-225_slice_103.txt
# - sub-225_slice_125.txt
# - sub-225_slice_140.txt
# - sub-225_slice_145.txt
# - sub-225_slice_162.txt
# - sub-226_slice_030.txt
# - sub-226_slice_041.txt
# - sub-226_slice_045.txt
# - sub-226_slice_050.txt
# - sub-226_slice_071.txt
# - sub-226_slice_072.txt
# - sub-226_slice_076.txt
# - sub-226_slice_079.txt
# - sub-226_slice_094.txt
# - sub-226_slice_127.txt
# - sub-226_slice_143.txt
# - sub-227_slice_036.txt
# - sub-227_slice_058.txt
# - sub-227_slice_060.txt
# - sub-227_slice_067.txt
# - sub-227_slice_072.txt
# - sub-227_slice_088.txt
# - sub-227_slice_093.txt
# - sub-227_slice_125.txt
# - sub-227_slice_147.txt
# - sub-227_slice_167.txt
# - sub-227_slice_168.txt
# - sub-227_slice_171.txt
# - sub-227_slice_178.txt
# - sub-228_slice_046.txt
# - sub-228_slice_047.txt
# - sub-228_slice_048.txt
# - sub-228_slice_049.txt
# - sub-228_slice_050.txt
# - sub-228_slice_051.txt
# - sub-228_slice_052.txt
# - sub-228_slice_053.txt
# - sub-228_slice_054.txt
# - sub-228_slice_055.txt
# - sub-228_slice_088.txt
# - sub-228_slice_089.txt
# - sub-228_slice_090.txt
# - sub-228_slice_091.txt
# - sub-228_slice_092.txt
# - sub-228_slice_100.txt
# - sub-228_slice_101.txt
# - sub-228_slice_102.txt
# - sub-228_slice_103.txt
# - sub-228_slice_104.txt
# - sub-228_slice_105.txt
# - sub-228_slice_106.txt
# - sub-228_slice_107.txt
# - sub-228_slice_108.txt
# - sub-228_slice_109.txt
# - sub-228_slice_110.txt
# - sub-228_slice_115.txt
# - sub-228_slice_124.txt
# - sub-228_slice_129.txt
# - sub-228_slice_156.txt
# - sub-228_slice_176.txt
# - sub-229_slice_052.txt
# - sub-229_slice_053.txt
# - sub-229_slice_098.txt
# - sub-229_slice_100.txt
# - sub-229_slice_110.txt
# - sub-229_slice_118.txt
# - sub-229_slice_126.txt
# - sub-229_slice_127.txt
# - sub-229_slice_128.txt
# - sub-229_slice_134.txt
# - sub-229_slice_135.txt
# - sub-229_slice_150.txt
# - sub-229_slice_182.txt
# - sub-229_slice_190.txt
# - sub-230_slice_031.txt
# - sub-230_slice_057.txt
# - sub-230_slice_061.txt
# - sub-230_slice_067.txt
# - sub-230_slice_080.txt
# - sub-230_slice_087.txt
# - sub-230_slice_118.txt
# - sub-230_slice_125.txt
# - sub-230_slice_140.txt
# - sub-230_slice_143.txt
# - sub-230_slice_164.txt
# - sub-230_slice_173.txt
# - sub-230_slice_176.txt
# - sub-233_slice_042.txt
# - sub-233_slice_045.txt
# - sub-233_slice_059.txt
# - sub-233_slice_080.txt
# - sub-233_slice_111.txt
# - sub-233_slice_117.txt
# - sub-233_slice_118.txt
# - sub-233_slice_130.txt
# - sub-233_slice_142.txt
# - sub-233_slice_153.txt
# - sub-233_slice_158.txt
# - sub-233_slice_161.txt
# - sub-233_slice_186.txt
# - sub-234_slice_014.txt
# - sub-234_slice_021.txt
# - sub-234_slice_042.txt
# - sub-234_slice_045.txt
# - sub-234_slice_060.txt
# - sub-234_slice_061.txt
# - sub-234_slice_062.txt
# - sub-234_slice_075.txt
# - sub-234_slice_081.txt
# - sub-234_slice_082.txt
# - sub-234_slice_083.txt
# - sub-234_slice_084.txt
# - sub-234_slice_097.txt
# - sub-234_slice_098.txt
# - sub-234_slice_099.txt
# - sub-234_slice_100.txt
# - sub-234_slice_101.txt
# - sub-234_slice_102.txt
# - sub-234_slice_104.txt
# - sub-234_slice_140.txt
# - sub-234_slice_154.txt
# - sub-234_slice_166.txt
# - sub-301_slice_035.txt
# - sub-302_slice_004.txt
# - sub-302_slice_012.txt
# - sub-302_slice_022.txt
# - sub-302_slice_023.txt
# - sub-302_slice_024.txt
# - sub-302_slice_029.txt
# - sub-302_slice_037.txt
# - sub-303_slice_020.txt
# - sub-303_slice_025.txt
# - sub-303_slice_032.txt
# - sub-303_slice_033.txt
# - sub-303_slice_039.txt
# - sub-303_slice_046.txt
# - sub-304_slice_013.txt
# - sub-304_slice_014.txt
# - sub-304_slice_020.txt
# - sub-304_slice_032.txt
# - sub-305_slice_003.txt
# - sub-305_slice_005.txt
# - sub-305_slice_012.txt
# - sub-305_slice_013.txt
# - sub-305_slice_017.txt
# - sub-305_slice_018.txt
# - sub-305_slice_031.txt
# - sub-306_slice_005.txt
# - sub-306_slice_013.txt
# - sub-306_slice_033.txt
# - sub-306_slice_034.txt
# - sub-307_slice_003.txt
# - sub-307_slice_005.txt
# - sub-307_slice_015.txt
# - sub-307_slice_017.txt
# - sub-307_slice_019.txt
# - sub-307_slice_020.txt
# - sub-307_slice_023.txt
# - sub-307_slice_032.txt
# - sub-309_slice_006.txt
# - sub-309_slice_012.txt
# - sub-309_slice_016.txt
# - sub-309_slice_022.txt
# - sub-309_slice_031.txt
# - sub-310_slice_006.txt
# - sub-310_slice_031.txt
# - sub-311_slice_003.txt
# - sub-311_slice_013.txt
# - sub-311_slice_014.txt
# - sub-312_slice_009.txt
# - sub-312_slice_018.txt
# - sub-312_slice_019.txt
# - sub-312_slice_023.txt
# - sub-312_slice_024.txt
# - sub-313_slice_009.txt
# - sub-313_slice_023.txt
# - sub-313_slice_026.txt
# - sub-314_slice_022.txt
# - sub-315_slice_025.txt
# - sub-315_slice_026.txt
# - sub-315_slice_029.txt
# - sub-315_slice_035.txt
# - sub-316_slice_008.txt
# - sub-316_slice_013.txt
# - sub-316_slice_015.txt
# - sub-316_slice_019.txt
# - sub-316_slice_027.txt
# - sub-318_slice_002.txt
# - sub-318_slice_003.txt
# - sub-318_slice_006.txt
# - sub-318_slice_016.txt
# - sub-319_slice_002.txt
# - sub-319_slice_007.txt
# - sub-319_slice_013.txt
# - sub-319_slice_020.txt
# - sub-319_slice_028.txt
# - sub-320_slice_001.txt
# - sub-320_slice_013.txt
# - sub-320_slice_018.txt
# - sub-320_slice_028.txt
# - sub-322_slice_023.txt
# - sub-322_slice_024.txt
# - sub-322_slice_025.txt
# - sub-322_slice_029.txt
# - sub-322_slice_035.txt
# - sub-322_slice_036.txt
# - sub-323_slice_021.txt
# - sub-323_slice_022.txt
# - sub-323_slice_026.txt
# - sub-324_slice_004.txt
# - sub-324_slice_013.txt
# - sub-324_slice_014.txt
# - sub-325_slice_018.txt
# - sub-325_slice_019.txt
# - sub-325_slice_023.txt
# - sub-325_slice_025.txt
# - sub-325_slice_026.txt
# - sub-326_slice_024.txt
# - sub-326_slice_025.txt
# - sub-327_slice_020.txt
# - sub-327_slice_035.txt
# 717
