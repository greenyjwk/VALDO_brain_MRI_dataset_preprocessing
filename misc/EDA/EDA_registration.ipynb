# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
uid = 319
slice = 20

# %%
# T1 = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-{uid}/T1_sub-{uid}.nii.gz")
# T1 = T1.get_fdata()

# T2 = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-{uid}/T2_sub-{uid}.nii.gz")
# T2 = T2.get_fdata()

# T2S = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-{uid}/T2S_sub-{uid}.nii.gz")
# T2S = T2S.get_fdata()

T1 = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T1.nii.gz")
T1 = T1.get_fdata()

T2 = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T2.nii.gz")
T2 = T2.get_fdata()

T2S = nib.load(f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T2S.nii.gz")
T2S = T2S.get_fdata()

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.imshow(np.rot90(T1[:,:,slice], k=1), cmap='gray')
plt.title('T1')

plt.subplot(132)
plt.imshow(np.rot90(T2[:,:,slice], k=1), cmap='gray')
plt.title('T2')

plt.subplot(133)
plt.imshow(np.rot90(T2S[:,:,slice], k=1), cmap='gray')
plt.title('T2S')
# Out:
# Text(0.5, 1.0, 'T2S')

# %%
print(np.min(T2S[:,:,slice]))
print(np.max(T2S[:,:,slice]))
print(np.mean(T2S[:,:,slice]))
# Out:
# 0.0
# 147.0
# 19.005096435546875
