# %%
import nibabel as nib
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
import matplotlib.image as mpimg

# %%
# img = nib.load("/mnt/storage/ji/VALDO_preprocessing/final/sub-108/sub-108.nii.gz")

mrn = 4918736
img = nib.load(f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_stacked/{mrn}/{mrn}.nii.gz")
img = img.get_fdata()
slice = 11
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 mrn = 4918736
#       4 img = nib.load(f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_stacked/{mrn}/{mrn}.nii.gz")
# ----> 5 img = img.get_fdata()
#       6 slice = 11
#
# File ~/miniconda3/envs/brainmri/lib/python3.10/site-packages/nibabel/dataobj_images.py:374, in DataobjImage.get_fdata(self, caching, dtype)
#     370         return self._fdata_cache
#     371 # Always return requested data type
#     372 # For array proxies, will attempt to confine data array to dtype
#     373 # during scaling
# --> 374 data = np.asanyarray(self._dataobj, dtype=dtype)
#     375 if caching == 'fill':
#     376     self._fdata_cache = data
#
# File ~/miniconda3/envs/brainmri/lib/python3.10/site-packages/nibabel/arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
# ...

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 3, 1)
plt.imshow(np.rot90(img[:,:,slice,0], k=1), cmap='gray')
plt.title('T1 Image_ch0')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(np.rot90(img[:,:,slice,1], k=1), cmap='gray')
plt.title('T2 Image_ch1')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(np.rot90(img[:,:,slice,2], k=1), cmap='gray')
plt.title('T2S Image_ch2')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
# data = nib.load("/mnt/storage/ji/VALDO_preprocessing/Preprocessed_v2/sub-108/sub-108_space-T2S_T2S.nii.gz")
# data = data.get_fdata()
# print(data.shape)
# plt.imshow(data[:,:,20], cmap='gray')

# %%
# Path to the PNG file
png_file_path = f"/media/Datacenter_storage/Ji/mayo_yolo_dataset_temp/yolo_dataset/images/test/{mrn}_{slice}.png"

# Load the image
img = mpimg.imread(png_file_path)
# Display the image
plt.imshow(img, cmap='gray')
plt.axis('off')  # Hide the axis
plt.title('PNG Image')
plt.show()

# %%
# Path to the PNG file
png_file_path = f"/media/Datacenter_storage/Ji/mayo_yolo_dataset2/visualized_boxes/{mrn}_{slice}_boxes.png"

# Load the image
img = mpimg.imread(png_file_path)
# Display the image
plt.imshow(img, cmap='gray')
plt.axis('off')  # Hide the axis
plt.title('PNG Image')
plt.show()

# %%
# Path to the PNG file
png_file_path = f"/media/Datacenter_storage/Ji/mayo_yolo_dataset_temp/yolo_dataset/images/test/{mrn}_{slice}.png"

# Load the image
img = mpimg.imread(png_file_path)
print(img.shape)


plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')
plt.axis('off')  # Hide the axis
plt.title('T1')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')
plt.axis('off')  # Hide the axis
plt.title('T2')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
plt.axis('off')  # Hide the axis
plt.title('T2 STAR')


# # Display the image
# plt.imshow(img[:,:,2], cmap='gray')
# plt.axis('off')  # Hide the axis
# plt.title('PNG Image')
# plt.show()
# Out:
# (256, 256, 3)
# Text(0.5, 1.0, 'T2 STAR')

# %% [markdown]
# # Mayo Dataset

# %% [markdown]
# ### T1_after NIFFLER

# %%
slice = 80
file_path = "/media/Datacenter_storage/Ji/3D_SAG_T1_MPRAGE_1MM/extracted-images/8db7012d2964db371f065b4f7ac5729ca67e00c14aa2f2204fb5f668/839bc5307b7a7aa07a24cfc9bdefddde5f2b37c39ffad545be51139f/3459c76c479f5b088e3ebf9691971490d3787e96348207fba4f77975/4759387_1.2.840.114350.2.451.2.798268.2.2222683937857.1_1.3.12.2.1107.5.2.19.45327.2020083015064377672538699.0.0.0.nii.gz"
img=nib.load(file_path)
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:,:,slice], cmap='gray')
# Out:
# (208, 240, 256)

# %% [markdown]
# ### T1 Bias-Field-Correction

# %%
slice = 28
file_path = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_bias_field_correction/4759387/3D_SAG_T1_MPRAGE_1MM_4759387.nii.gz"
img=nib.load(file_path)
img = img.get_fdata()
plt.imshow(img[:,:,slice], cmap='gray')

# %% [markdown]
# ### T2 Niffler

# %%
file_path = "/media/Datacenter_storage/Ji/SAG_3D_T2_SPACE/extracted-images/8db7012d2964db371f065b4f7ac5729ca67e00c14aa2f2204fb5f668/839bc5307b7a7aa07a24cfc9bdefddde5f2b37c39ffad545be51139f/3edbf0613a7c443222b8ff0c1c671e298544ea580fa6ffd031e31827/4759387_1.2.840.114350.2.451.2.798268.2.2222683937857.1_1.3.12.2.1107.5.2.19.45327.2020083015224462260243195.0.0.0.nii.gz"
img=nib.load(file_path)
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:,:,slice], cmap='gray')
# Out:
# (192, 240, 256)

# %% [markdown]
# ### T2 Registration

# %%
file_path = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_registered/4759387/SAG_3D_T2_SPACE_4759387.nii.gz"
img=nib.load(file_path)
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:,:,slice], cmap='gray')
# Out:
# (256, 256, 44)

# %% [markdown]
# ### T2 Bias Field Correction

# %%
file_path = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_bias_field_correction/4759387/SAG_3D_T2_SPACE_4759387.nii.gz"
img=nib.load(file_path)
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:,:,slice], cmap='gray')
# Out:
# (256, 256, 44)

# %% [markdown]
# ### T2 STAR Bias field Correction

# %%
file_path = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_bias_field_correction/4759387/Axial_3TE_T2_STAR_4759387.nii.gz"
img=nib.load(file_path)
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:,:,slice], cmap='gray')
# Out:
# (256, 256, 44)

# %% [markdown]
# ### T1, T2, T2* Stacked

# %%
file_path = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_stacked/4759387/4759387.nii.gz"

img =nib.load(file_path)
img = img.get_fdata()


plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img[:,:,slice,0], cmap='gray')
plt.title("t1")

plt.subplot(1,3,2)
plt.imshow(img[:,:,slice,1], cmap='gray')
plt.title("t2")

plt.subplot(1,3,3)
plt.imshow(img[:,:,slice,2], cmap='gray')
plt.title("t2*")
# Out:
# Text(0.5, 1.0, 't2*')
