# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %% [markdown]
# ### stacked sequence order checking

# %%
slice = 27
uid = 201
file_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_stacked_temp/55/55.nii.gz"

img = nib.load(file_path)
img = img.get_fdata()

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img[: ,:, slice,0], cmap = 'gray')
plt.title("T1 Image_ch0")

plt.subplot(1,3,2)
plt.imshow(img[: ,:, slice,1], cmap = 'gray')
plt.title("T2 Image_ch1")

plt.subplot(1,3,3)
plt.imshow(img[: ,:, slice,2], cmap = 'gray')
plt.title("T2* Image_ch2")
# Out:
# Text(0.5, 1.0, 'T2* Image_ch2')

# %% [markdown]
# ### Sequence Selection

# %%
file_path1 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo/sub-{uid}/T1_sub-{uid}.nii.gz"
img1 = nib.load(file_path1)
img1 = img1.get_fdata()

file_path2 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo/sub-{uid}/T2_sub-{uid}.nii.gz"
img2 = nib.load(file_path2)
img2 = img2.get_fdata()

file_path3 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo/sub-{uid}/T2S_sub-{uid}.nii.gz"
img3 = nib.load(file_path3)
img3 = img3.get_fdata()

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img1[: ,:, slice], cmap = 'gray')
plt.title("T1 Image_ch0")

plt.subplot(1,3,2)
plt.imshow(img2[: ,:, slice], cmap = 'gray')
plt.title("T2 Image_ch1")

plt.subplot(1,3,3)
plt.imshow(img3[: ,:, slice], cmap = 'gray')
plt.title("T2* Image_ch2")
# Out:
# Text(0.5, 1.0, 'T2* Image_ch2')

# %% [markdown]
# ### After registration

# %%
file_path1 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_registered/sub-{uid}/T1_sub-{uid}.nii.gz"
img1 = nib.load(file_path1)
img1 = img1.get_fdata()

file_path2 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_registered/sub-{uid}/T2_sub-{uid}.nii.gz"
img2 = nib.load(file_path2)
img2 = img2.get_fdata()

file_path3 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_registered/sub-{uid}/T2S_sub-{uid}.nii.gz"
img3 = nib.load(file_path3)
img3 = img3.get_fdata()


plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img1[:, :, slice], cmap = 'gray')
plt.title("T1 Image_ch0")

plt.subplot(1,3,2)
plt.imshow(img2[:, :, slice], cmap = 'gray')
plt.title("T2 Image_ch1")

plt.subplot(1,3,3)
plt.imshow(img3[:, :, slice], cmap = 'gray')
plt.title("T2* Image_ch2")
# Out:
# Text(0.5, 1.0, 'T2* Image_ch2')

# %% [markdown]
# ### After Skull-stripped

# %%
file_path1 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-{uid}/T1_sub-{uid}.nii.gz"
img1 = nib.load(file_path1)
img1 = img1.get_fdata()

file_path2 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-{uid}/T2_sub-{uid}.nii.gz"
img2 = nib.load(file_path2)
img2 = img2.get_fdata()

file_path3 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-{uid}/T2S_sub-{uid}.nii.gz"
img3 = nib.load(file_path3)
img3 = img3.get_fdata()

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img1[:, :, slice], cmap = 'gray')
plt.title("T1 Image_ch0")

plt.subplot(1,3,2)
plt.imshow(img2[:, :, slice], cmap = 'gray')
plt.title("T2 Image_ch1")

plt.subplot(1,3,3)
plt.imshow(img3[:, :, slice], cmap = 'gray')
plt.title("T2* Image_ch2")
# Out:
# Text(0.5, 1.0, 'T2* Image_ch2')

# %% [markdown]
# ### Original Data

# %%
root = "/mnt/storage/cmb_segmentation_dataset/Task2"
file_path1 = f"{root}/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T1.nii.gz"
img1 = nib.load(file_path1)
img1 = img1.get_fdata()

file_path2 = f"{root}/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T2.nii.gz"
img2 = nib.load(file_path2)
img2 = img2.get_fdata()

file_path3 = f"{root}/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T2S.nii.gz"
img3 = nib.load(file_path3)
img3 = img3.get_fdata()


plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(img1[:, :, slice], cmap = 'gray')
plt.title("T1 Image_ch0")

plt.subplot(1,3,2)
plt.imshow(img2[:, :, slice], cmap = 'gray')
plt.title("T2 Image_ch1")

plt.subplot(1,3,3)
plt.imshow(img3[:, :, slice], cmap = 'gray')
plt.title("T2* Image_ch2")
# Out:
# Text(0.5, 1.0, 'T2* Image_ch2')
