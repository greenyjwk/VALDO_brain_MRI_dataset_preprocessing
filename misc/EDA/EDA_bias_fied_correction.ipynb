# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
uid = 307
slice = 26

# %%
root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction"

T1 = nib.load(f"{root_path}/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T1.nii.gz")
T1 = T1.get_fdata()

T2 = nib.load(f"{root_path}/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T2.nii.gz")
T2 = T2.get_fdata()

T2S = nib.load(f"{root_path}/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T2S.nii.gz")
T2S = T2S.get_fdata()
print("T2S.shape:: ", T2S.shape)
# Out:
# T2S.shape::  (512, 512, 39)

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.imshow((T1[:,:,slice]), cmap='gray', origin='lower')
plt.title('T1')

plt.subplot(132)
plt.imshow((T2[:,:,slice]), cmap='gray', origin='lower')
plt.title('T2')

plt.subplot(133)
plt.imshow((T2S[:,:,slice]), cmap='gray', origin='lower')
plt.title('T2S')
# Out:
# Text(0.5, 1.0, 'T2S')
