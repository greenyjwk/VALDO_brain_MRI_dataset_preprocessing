# %%
# If using nibabel
import nibabel as nib
import matplotlib.pyplot as plt

# %%
orig = nib.load('/mnt/storage/ji/brain_mri_valdo_mayo/valdo_registered/sub-303/T1_sub-303.nii.gz')
stripped = nib.load('/mnt/storage/ji/brain_mri_valdo_mayo/valdo_skull_stripped/sub-303/T1_sub-303.nii.gz')
stripped_data = stripped.get_fdata()
mask = stripped_data > 0
final = orig.get_fdata() * mask

# %%
plt.imshow(final[:, :, 15], cmap='gray')
