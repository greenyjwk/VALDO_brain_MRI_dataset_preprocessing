# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image

# %%
img_path = os.path.join("/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_t2s_GAN_3slices/images/train/sub-216_slice_084.png")
img = Image.open(img_path)
img = np.array(img)

plt.figure(figsize=(10, 10))

plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
# Out:
# (2048, 2048, 3)
