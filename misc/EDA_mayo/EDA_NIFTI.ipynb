# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
mrn = 12873856
slice = 20
slice_T2S= int(44 * (slice/256))
print(slice_T2S)
sub_root ="mayo_resampled_correctly_resampled"
# Out:
# 3

# %%
img_path = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/3D_SAG_T1_MPRAGE_1MM_{mrn}.nii.gz"
img = nib.load(img_path)
header=img.header
print(header['pixdim'])

img = img.get_fdata()
print(img.shape)

plt.imshow(img[:, :, slice], cmap='gray')
# Out:
# [-1.        0.859375  0.859375  4.        0.        0.        0.
#   0.      ]
# (242, 279, 64)

# %%
img_path = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/SAG_3D_T2_SPACE_{mrn}.nii.gz"
img = nib.load(img_path)
header=img.header
print(header['pixdim'])
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:, :, slice], cmap='gray')
# Out:
# [-1.        0.859375  0.859375  4.        0.        0.        0.
#   0.      ]
# (223, 279, 64)

# %%
img_path = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/Axial_3TE_T2_STAR_{mrn}.nii.gz"
img = nib.load(img_path)
header=img.header
print(header['pixdim'])
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:, :, slice, 0], cmap='gray')
# Out:
# [-1.        0.859375  0.859375  4.        1.        1.        1.
#   1.      ]
# (256, 256, 44, 3)
