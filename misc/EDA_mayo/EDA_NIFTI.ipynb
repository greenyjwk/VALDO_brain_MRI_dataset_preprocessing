# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import pydicom

# %% [markdown]
# ### Original Valdo NIFTI

# %%
# # original_file_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction_resampled_05mm/sub-111/sub-111_space-T2S_desc-masked_T2S.nii.gz"
# # original_file_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction_resampled_05mm/sub-215/sub-215_space-T2S_desc-masked_T2S.nii.gz"
original_file_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_MAYO/mayo_allsequence/4867541/SAG_3D_T2_SPACE_4867541.nii.gz"

file_data = nib.load(original_file_path)
# print(file_data)
file_data = file_data.get_fdata()
print(file_data.shape)

plt.figure(figsize=(10, 10))
plt.imshow(file_data[:, :, 20], cmap='gray')
# Out:
# (512, 512, 35)

# %%
# file_path_0 = f"/mnt/storage/ji/csf_segment/{uid}/T1_seg_0.nii.gz"
# # file_path_0 = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction/sub-201/sub-201_space-T2S_desc-masked_T1.nii.gz"

# file_0 = nib.load(file_path_0)
# img_0 = file_0.get_fdata()

# plt.figure(figsize=(10, 10))
# plt.subplot(1, 2, 1)
# plt.imshow(np.rot90(img_0[:, :, slice_num]), cmap='gray')

# %%
# /mnt/storage/ji/csf_segment/3/_seg_0.nii.gzfile_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-305/sub-305_space-T2S_desc-masked_T2S.nii.gz"
mask_path = f"/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-{uid}/sub-{uid}_space-T2S_CMB.nii.gz"
mask = nib.load(mask_path)
mask = mask.get_fdata()
print("mask.shape: ", mask.shape)
print(np.unique(mask))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # /mnt/storage/ji/csf_segment/3/_seg_0.nii.gzfile_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-305/sub-305_space-T2S_desc-masked_T2S.nii.gz"
# ----> 2 mask_path = f"/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-{uid}/sub-{uid}_space-T2S_CMB.nii.gz"
#       3 mask = nib.load(mask_path)
#       4 mask = mask.get_fdata()
#
# NameError: name 'uid' is not defined

# %%
for slice in range(mask.shape[2]):
    if len(np.unique(mask[:,:,slice]))==2:
        print("slice: ", slice)
# Out:
# slice:  23
# slice:  24
# slice:  25

# %%
plt.imshow(mask[:, :, slice_num], cmap='gray')

# %%
plt.imshow(file_data[:, :, slice_num], cmap='gray', alpha=0.8)
mask_slice = mask[:, :, slice_num]
plt.imshow(np.ma.masked_where(mask_slice == 1, mask_slice), 
           cmap='Reds', alpha=0.5)
plt.title('Overlay')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
mask_path  = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/3ch_stacked/sub-108/sub-108_mask.nii.gz"
nii_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/3ch_stacked/sub-207/sub-207.nii.gz"

mask_data = nib.load(mask_path)
img_data = nib.load(nii_path)

mask_data = mask_data.get_fdata()
img_data = img_data.get_fdata()

print(img_data.shape)
plt.imshow(img_data[:,:,10,2], cmap='gray')
# Out:
# (512, 512, 192, 3)

# %%
t1_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-207/sub-207_space-T2S_desc-masked_T1.nii.gz"
# t2_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-207/sub-207_space-T2S_desc-masked_T2.nii.gz"
# t2s_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-207/sub-207_space-T2S_desc-masked_T2S.nii.gz"

t1_data = nib.load(t1_path)
t1_data = t1_data.get_fdata()
print(t1_data.shape)
plt.imshow(t1_data[:,:,20])
# Out:
# (512, 512, 192)

# %%
# t1_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-207/sub-207_space-T2S_desc-masked_T1.nii.gz"
t2_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-207/sub-207_space-T2S_desc-masked_T2.nii.gz"
# t2s_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/bias_field_correction/sub-207/sub-207_space-T2S_desc-masked_T2S.nii.gz"
t2_data = nib.load(t2_path)
t2_data = t2_data.get_fdata()
print(t2_data.shape)
plt.imshow(t2_data[:,:,20])
# Out:
# (512, 512, 192)

# %%
path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_MAYO/mayo_t2s/5816440/5816440.nii.gz"
data = nib.load(path)
data = data.get_fdata()
print(data.shape)
plt.imshow(data[:,:,20], cmap='gray')
# Out:
# (256, 256, 44)
