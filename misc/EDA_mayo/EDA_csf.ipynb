# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
slice_num = 25
MRN = "4817777"

# %%
file_path_0 = f"/media/Datacenter_storage/Ji/csf_segment_threshold/{MRN}/T1_seg_0.nii.gz"
file_0 = nib.load(file_path_0)
img_0 = file_0.get_fdata()

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(np.rot90(img_0[:, :, slice_num]), cmap='gray')
plt.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)
