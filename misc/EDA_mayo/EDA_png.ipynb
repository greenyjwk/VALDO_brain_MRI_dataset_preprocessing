# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# Path to the PNG file
png_file_path = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated_GAN/images/test/4796915_22.png"

# Open the image file
img = Image.open(png_file_path)
img = np.array(img)
print(img.shape)
# Display the image

plt.subplot(1,3,1)
plt.imshow(img[:, :,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
# Out:
# (1024, 1024, 3)
