# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# Path to the PNG file
png_file_path = "/media/Datacenter_storage/Ji/mayo_yolo_dataset_temp/yolo_dataset/images/test/12787711_10.png"

# Open the image file
img = Image.open(png_file_path)
img = np.array(img)
print(img.shape)
# Display the image

plt.subplot(1,3,1)
plt.imshow(img[:, :,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
# Out:
# (256, 256, 3)
