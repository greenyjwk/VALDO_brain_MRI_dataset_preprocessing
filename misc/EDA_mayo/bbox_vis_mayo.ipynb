# %%
import os
import cv2
import numpy as np
from pathlib import Path

# %%
def load_yolo_bbox(label_path):
    """
    Load YOLO format bounding boxes from a label file.
    Returns list of tuples (class_id, x_center, y_center, width, height)
    """
    boxes = []
    with open(label_path, 'r') as f:
        for line in f:
            # Parse YOLO format: class x_center y_center width height
            class_id, x_center, y_center, width, height, *confidence = map(float, line.strip().split())
            boxes.append((class_id, x_center, y_center, width, height))
    return boxes

def yolo_to_pixel_coords(box, img_width, img_height):
    """
    Convert YOLO format (x_center, y_center, width, height) to pixel coordinates
    Returns (x_min, y_min, x_max, y_max)
    """
    x_center, y_center, width, height = box[1:]
    
    # Convert from relative coordinates to absolute pixels
    x_center = x_center * img_width
    y_center = y_center * img_height
    width = width * img_width
    height = height * img_height
    
    # Calculate corners
    x_min = int(x_center - width/2)
    y_min = int(y_center - height/2)
    x_max = int(x_center + width/2)
    y_max = int(y_center + height/2)
    
    # Ensure coordinates are within image bounds
    x_min = max(0, x_min)
    y_min = max(0, y_min)
    x_max = min(img_width, x_max)
    y_max = min(img_height, y_max)
    
    return x_min, y_min, x_max, y_max

def extract_patches(image_dir, label_dir, output_dir=None, patch_size=32):
    """
    Extract patches from images based on YOLO format bounding boxes.
    Patches will be expanded to patch_size x patch_size while maintaining their center point.
    If output_dir is provided, saves patches to files.
    Otherwise, displays them using cv2.imshow()
    """
    image_dir = Path(image_dir)
    label_dir = Path(label_dir)
    
    if output_dir:
        output_dir = Path(output_dir)
        output_dir.mkdir(parents=True, exist_ok=True)
    
    # Process all PNG files that have corresponding label files
    for img_path in image_dir.glob('*.png'):
        # Find corresponding label file
        label_path = label_dir / f"{img_path.stem}.txt"
        if not label_path.exists():
            print(f"No label file found for {img_path}")
            continue
            
        # Read image and get dimensions
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"Could not read image {img_path}")
            continue
            
        img_height, img_width = img.shape[:2]
        
        # Load bounding boxes
        boxes = load_yolo_bbox(label_path)
        
        # Extract and save/display patches
        for i, box in enumerate(boxes):
            x_min, y_min, x_max, y_max = yolo_to_pixel_coords(box, img_width, img_height)
            
            # Calculate center point
            x_center = (x_min + x_max) // 2
            y_center = (y_min + y_max) // 2
            
            # Calculate new boundaries for fixed-size patch
            half_size = patch_size // 2
            x_min = max(0, x_center - half_size)
            x_max = min(img_width, x_center + half_size)
            y_min = max(0, y_center - half_size)
            y_max = min(img_height, y_center + half_size)
            
            # Handle edge cases where patch would go outside image bounds
            if x_max - x_min < patch_size:
                if x_min == 0:  # If we hit the left edge
                    x_max = min(img_width, patch_size)
                else:  # If we hit the right edge
                    x_min = max(0, img_width - patch_size)
                    
            if y_max - y_min < patch_size:
                if y_min == 0:  # If we hit the top edge
                    y_max = min(img_height, patch_size)
                else:  # If we hit the bottom edge
                    y_min = max(0, img_height - patch_size)
            
            # Extract patch
            patch = img[y_min:y_max, x_min:x_max]
            
            if patch.size == 0:
                print(f"Warning: Empty patch extracted from {img_path.name}, box {i}")
                continue
                
            if output_dir:
                # Save patch
                patch_path = output_dir / f"{img_path.stem}_patch_{i}.png"
                try:
                    cv2.imwrite(str(patch_path), patch)
                except Exception as e:
                    print(f"Error saving patch from {img_path.name}, box {i}: {str(e)}")
                    print(f"Patch shape: {patch.shape}")
            else:
                # Display patch
                cv2.imshow(f"Patch {i} from {img_path.name}", patch)
                cv2.waitKey(0)
                
    if not output_dir:
        cv2.destroyAllWindows()

# Example usage
def visualize_boxes(image_dir, label_dir, output_dir=None, patch_size=32):
    """
    Visualize both original and expanded bounding boxes on the images.
    Red box: Original YOLO bounding box
    Green box: Expanded 32x32 box
    """
    image_dir = Path(image_dir)
    label_dir = Path(label_dir)
    
    if output_dir:
        output_dir = Path(output_dir)
        output_dir.mkdir(parents=True, exist_ok=True)
    
    for img_path in image_dir.glob('*.png'):
        # Find corresponding label file
        label_path = label_dir / f"{img_path.stem}.txt"
        if not label_path.exists():
            continue
            
        # Read image and get dimensions
        img = cv2.imread(str(img_path))
        if img is None:
            continue
            
        img_height, img_width = img.shape[:2]
        vis_img = img.copy()
        
        # Load bounding boxes
        boxes = load_yolo_bbox(label_path)
        
        for i, box in enumerate(boxes):
            # Get original box coordinates
            x_min, y_min, x_max, y_max = yolo_to_pixel_coords(box, img_width, img_height)
            
            # # Draw original box in red
            # cv2.rectangle(vis_img, (x_min, y_min), (x_max, y_max), (0, 0, 255), 1)
            
            # Calculate expanded box coordinates
            x_center = (x_min + x_max) // 2
            y_center = (y_min + y_max) // 2
            
            half_size = patch_size // 2
            exp_x_min = max(0, x_center - half_size)
            exp_x_max = min(img_width, x_center + half_size)
            exp_y_min = max(0, y_center - half_size)
            exp_y_max = min(img_height, y_center + half_size)
            
            # Handle edge cases
            if exp_x_max - exp_x_min < patch_size:
                if exp_x_min == 0:
                    exp_x_max = min(img_width, patch_size)
                else:
                    exp_x_min = max(0, img_width - patch_size)
                    
            if exp_y_max - exp_y_min < patch_size:
                if exp_y_min == 0:
                    exp_y_max = min(img_height, patch_size)
                else:
                    exp_y_min = max(0, img_height - patch_size)
            
            # Draw expanded box in green
            cv2.rectangle(vis_img, (exp_x_min, exp_y_min), (exp_x_max, exp_y_max), (0, 255, 0), 1)
            
        if output_dir:
            # Save visualization
            vis_path = output_dir / f"{img_path.stem}_boxes.png"
            cv2.imwrite(str(vis_path), vis_img)
        else:
            # Display visualization
            cv2.imshow(f"Boxes - {img_path.name}", vis_img)
            cv2.waitKey(0)
    
    if not output_dir:
        cv2.destroyAllWindows()

if __name__ == "__main__":
    image_dir = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated"
    label_dir = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/labels/test/rotated"
    
    # Extract patches
    output_dir = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_vis/extracted_patches"
    extract_patches(image_dir, label_dir, output_dir, patch_size=16)
    
    # Visualize boxes
    vis_output_dir = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_vis/visualized_boxes"
    visualize_boxes(image_dir, label_dir, vis_output_dir, patch_size=16)
# Out:
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6769837_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4806209_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5809343_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4796915_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5771968_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5938862_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12787711_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4806209_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4965141_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5808373_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4911001_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10745491_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4838643_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4910831_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4806209_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4952456_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5834851_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4796915_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4817373_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10869254_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7623266_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5827390_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6780698_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12336742_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5809343_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12595866_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5834809_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4962582_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7632014_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995152_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5811558_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5808368_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4990472_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6807682_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6926040_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10863578_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5929128_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4990472_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867541_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5820695_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5854417_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7967383_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4881849_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6990786_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7800567_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7517769_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5820695_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556853_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10857463_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7517769_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7623266_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7678804_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995152_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967524_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7632014_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5790129_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6834098_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5827390_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10863578_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4796915_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4911001_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5778204_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4952456_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5987394_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10908421_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7503261_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7797334_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7995053_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4911001_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7969346_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5820695_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4838643_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4937386_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4952456_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6990786_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4759387_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6920455_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5770043_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12336742_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5811558_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4806209_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556853_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6780692_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5886223_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4965141_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7517769_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6782776_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4869073_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10765931_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10757098_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5957595_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5778358_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5938862_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828635_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7632014_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4960636_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4965141_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5838291_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5778358_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4798157_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7623266_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4806209_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6945935_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4981854_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4953391_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556823_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10757098_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5773274_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4838643_38.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4960636_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5771968_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7975730_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5877327_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7833902_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556823_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7517769_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995152_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4817777_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5771968_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967524_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4981854_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6940170_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7969346_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4918736_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5878129_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5773274_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5770043_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5886223_38.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4910831_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5929128_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10869254_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4910831_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5938862_12.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7975730_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556823_12.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7517769_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867588_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10869254_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5987394_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6991743_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4937386_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5834851_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6934580_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5957595_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5938862_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881689_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4836682_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995155_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967573_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12503291_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828635_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12873856_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12873856_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4981854_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10895233_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5827390_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6869926_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5931046_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995152_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10908421_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7969346_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5075599_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6780692_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4981854_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12503291_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6945935_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4918736_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12787711_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5809343_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6810080_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5878129_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967524_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5820695_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6810080_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7874875_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6810080_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4798157_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7995053_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4965141_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881689_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6991743_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5808373_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4911001_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12235430_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12151060_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4881849_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881689_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10745491_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967573_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6769837_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5768637_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4952456_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5790129_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5811558_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5878129_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5811558_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4911001_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6990786_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10734610_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12787711_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867588_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7975730_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995152_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6992446_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6782776_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881558_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4962582_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4981854_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867541_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5809343_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5987394_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7874875_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4759387_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7995053_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7678804_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5831500_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10908421_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12235430_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12151060_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867541_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4953391_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12151060_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7867995_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7874875_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6992446_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7503261_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5790129_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828635_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10734610_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5987394_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4960636_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5808368_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7503261_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12595866_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7797334_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10791512_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4945862_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828151_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_12.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556823_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6940170_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6940170_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7967383_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4817373_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10857463_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10757098_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10869254_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6926040_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867541_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12235430_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7623266_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5834851_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828635_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4953391_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5075599_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12336742_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7833902_12.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10765931_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6934580_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7975730_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881558_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6807682_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7995053_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7967383_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7995053_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10869254_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6811746_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6810080_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6780698_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828151_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6992446_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7632014_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4906587_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995155_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10908421_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4960636_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7874875_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5938862_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881558_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10790863_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6780692_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5854417_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7556853_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5896685_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6917326_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10757098_39.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6920455_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6834098_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7800567_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4962582_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4817373_38.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5886223_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10906234_37.png
# ...
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5827390_38.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7787993_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10857463_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6940170_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4910831_22.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6834098_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5075599_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12147280_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10791512_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7517769_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6811746_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7797334_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6807682_24.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881689_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967524_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7975730_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5752998_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5773274_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4806209_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7833902_19.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6934580_34.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5854417_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4838643_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10863578_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4906587_38.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10869254_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967573_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5834809_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5778204_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4962582_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7995053_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828151_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5987394_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10745491_2.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_28.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5831500_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10791512_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6945935_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7797334_12.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6926040_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7975730_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12235430_31.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12873856_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6807682_10.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4937386_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10791512_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4796915_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5878129_1.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6780698_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10906234_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7564541_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6934580_4.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4838643_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5881689_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6992446_41.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10813100_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10857463_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5808373_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5929128_38.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5987394_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7511809_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5790129_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5957595_15.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7867995_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4796915_43.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10906234_30.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5995158_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828635_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12235430_29.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12787711_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/12595866_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_26.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10745491_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4911001_21.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/10791512_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4910831_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5790129_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5075599_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5886223_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5967524_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6782776_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5828635_23.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4836682_27.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4937386_40.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6782776_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4867588_35.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7969346_9.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5778204_8.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5838291_6.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4960636_32.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7867995_18.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7969346_14.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5785841_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6869926_13.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5834809_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4838643_20.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7503261_36.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4937386_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5808373_11.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7623266_17.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6926040_25.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7874875_0.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/7967074_7.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4869073_37.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5809343_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5938862_33.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5816440_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/6782776_16.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5790129_3.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_42.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/4965141_5.png
# No label file found for /media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_yolo_t2s_only_rotated/images/test/rotated/5835693_5.png
