# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
slice_num = 159
uid = 217

# %%
file_path_0 = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction/sub-{uid}/sub-{uid}_space-T2S_desc-masked_T1.nii.gz"

file_0 = nib.load(file_path_0)
img_0 = file_0.get_fdata()
print(np.unique(img_0))

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)

plt.imshow(np.rot90(img_0[:, :, slice_num]), cmap='gray')
# Out:
# [-102.95835876 -102.95835114 -102.95833588 ... 2740.14990234 2742.15893555
#  2750.85131836]

# %%
file_path_0 = f"/mnt/storage/ji/csf_segment/{uid}/T1_seg_0.nii.gz"
# file_path_0 = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction/sub-201/sub-201_space-T2S_desc-masked_T1.nii.gz"

file_0 = nib.load(file_path_0)
img_0 = file_0.get_fdata()

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(np.rot90(img_0[:, :, slice_num]), cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/nibabel/loadsave.py:100, in load(filename, **kwargs)
#      99 try:
# --> 100     stat_result = os.stat(filename)
#     101 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/storage/ji/csf_segment/217/T1_seg_0.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 file_path_0 = f"/mnt/storage/ji/csf_segment/{uid}/T1_seg_0.nii.gz"
#       2 # file_path_0 = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction/sub-201/sub-201_space-T2S_desc-masked_T1.nii.gz"
# ----> 4 file_0 = nib.load(file_path_0)
#       5 img_0 = file_0.get_fdata()
#       7 plt.figure(figsize=(10, 10))
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/nibabel/loadsave.py:102, in load(filename, **kwargs)
#     100     stat_result = os.stat(filename)
#     101 except OSError:
# --> 102     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     103 if stat_result.st_size <= 0:
#     104     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: '/mnt/storage/ji/csf_segment/217/T1_seg_0.nii.gz'

# %%
# /mnt/storage/ji/csf_segment/3/_seg_0.nii.gzfile_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-305/sub-305_space-T2S_desc-masked_T2S.nii.gz"
file = nib.load(file_path)
img = file.get_fdata()
print("img.shape: ", img.shape)
print(np.unique(img))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 2
#       1 # /mnt/storage/ji/csf_segment/3/_seg_0.nii.gzfile_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA/sub-305/sub-305_space-T2S_desc-masked_T2S.nii.gz"
# ----> 2 file = nib.load(file_path)
#       3 img = file.get_fdata()
#       4 print("img.shape: ", img.shape)
#
# NameError: name 'file_path' is not defined

# %%
plt.imshow(img[:, :, slice_num], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[451], line 1
# ----> 1 plt.imshow(img[:, :, slice_num], cmap='gray')
#
# IndexError: index 110 is out of bounds for axis 2 with size 39
