# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
def visualize_bounding_boxes(image_path, label_path):
    image = Image.open(image_path)
    image = np.array(image)
    height, width = image.shape[:2]

    # Load the labels
    with open(label_path, 'r') as f:
        labels = f.readlines()

    # Parse the labels
    bboxes = []
    for label in labels:
        class_id, x_center, y_center, box_width, box_height = map(float, label.split())
        x_center *= width
        y_center *= height
        box_width *= width
        box_height *= height
        x_min = int(x_center - box_width / 2)
        y_min = int(y_center - box_height / 2)
        x_max = int(x_center + box_width / 2)
        y_max = int(y_center + box_height / 2)
        bboxes.append((class_id, x_min, y_min, x_max, y_max))

    # Plot the image
    plt.figure(figsize=(10, 10))
    plt.imshow(image, cmap='gray' if len(image.shape) == 2 else None)
    plt.axis('on')

    # Plot the bounding boxes
    for bbox in bboxes:
        class_id, x_min, y_min, x_max, y_max = bbox
        color = 'red' if class_id == 0 else 'blue'
        rect = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                              linewidth=1, edgecolor=color, facecolor='none')
        plt.gca().add_patch(rect)
        # plt.text(x_min, y_min - 5, f'Class {int(class_id)}', color=color, fontsize=5, weight='bold')
        plt.text(x_min, y_min - 5, f'Class {int(class_id)}', color=color, fontsize=5)

    plt.title("Bounding Boxes Visualization")
    plt.show()

# Example usage
# /media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/csf_png/csf_labels/train/sub-228_slice_055.txt
uid = "207"
slice_num = "091"
task = "train"

# root_path = "/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_GAN_cmbOnly_2class_csf"

root_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/csf_png_for_biomedparse_cmbonly"
image_path = f"{root_path}/images/{task}/sub-{uid}_slice_{slice_num}.png"

root_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/csf_png_for_biomedparse_cmbonly"
label_path = f"{root_path}/labels/{task}/sub-{uid}_slice_{slice_num}.txt"
visualize_bounding_boxes(image_path, label_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 55
#      53 root_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/csf_png_for_biomedparse_cmbonly"
#      54 label_path = f"{root_path}/labels/{task}/sub-{uid}_slice_{slice_num}.txt"
# ---> 55 visualize_bounding_boxes(image_path, label_path)
#
# Cell In[9], line 2, in visualize_bounding_boxes(image_path, label_path)
#       1 def visualize_bounding_boxes(image_path, label_path):
# ----> 2     image = Image.open(image_path)
#       3     image = np.array(image)
#       4     height, width = image.shape[:2]
#
# File /media/Datacenter_storage/Ji/HOME_MEDIA/miniconda3/envs/medsam/lib/python3.10/site-packages/PIL/Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
# ...

# %%
def visualize_bounding_boxes(image_path, label_path):
    image = Image.open(image_path)
    image = np.array(image)
    height, width = image.shape[:2]

    # Load the labels
    with open(label_path, 'r') as f:
        labels = f.readlines()

    # Parse the labels
    bboxes = []
    for label in labels:
        class_id, x_center, y_center, box_width, box_height = map(float, label.split())
        x_center *= width
        y_center *= height
        box_width *= width
        box_height *= height
        x_min = int(x_center - box_width / 2)
        y_min = int(y_center - box_height / 2)
        x_max = int(x_center + box_width / 2)
        y_max = int(y_center + box_height / 2)
        bboxes.append((class_id, x_min, y_min, x_max, y_max))

    # Plot the image
    plt.figure(figsize=(10, 10))
    plt.imshow(image, cmap='gray' if len(image.shape) == 2 else None)
    plt.axis('on')

    # Plot the bounding boxes
    for bbox in bboxes:
        class_id, x_min, y_min, x_max, y_max = bbox
        color = 'red' if class_id == 0 else 'blue'
        rect = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                              linewidth=1, edgecolor=color, facecolor='none')
        plt.gca().add_patch(rect)
        # plt.text(x_min, y_min - 5, f'Class {int(class_id)}', color=color, fontsize=5, weight='bold')
        plt.text(x_min, y_min - 5, f'Class {int(class_id)}', color=color, fontsize=5)

    plt.title("Bounding Boxes Visualization")
    plt.show()

# Example usage
uid = "304"
slice_num = "020"
image_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_t2s_GAN_2class/images/train/sub-{uid}_slice_{slice_num}.png"
# label_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_t2s_GAN_2class/labels/train/sub-{uid}_slice_{slice_num}.txt"

label_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/TEMP3_train/labels/train/sub-{uid}_slice_{slice_num}.txt"
visualize_bounding_boxes(image_path, label_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 49
#      46 # label_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_t2s_GAN_2class/labels/train/sub-{uid}_slice_{slice_num}.txt"
#      48 label_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/TEMP3_train/labels/train/sub-{uid}_slice_{slice_num}.txt"
# ---> 49 visualize_bounding_boxes(image_path, label_path)
#
# Cell In[5], line 2, in visualize_bounding_boxes(image_path, label_path)
#       1 def visualize_bounding_boxes(image_path, label_path):
# ----> 2     image = Image.open(image_path)
#       3     image = np.array(image)
#       4     height, width = image.shape[:2]
#
# File /media/Datacenter_storage/Ji/HOME_MEDIA/miniconda3/envs/medsam/lib/python3.10/site-packages/PIL/Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
# ...

# %%
image_path = f"/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_t2s_GAN_cmbTrainOnly/images/train/sub-{uid}_slice_{slice_num}.png"

img = Image.open(image_path)
img = np.array(img)
print(img.shape)

# plt.imshow(img, cmap='gray' if len(img.shape) == 2 else None)
plt.imshow(img[:,:,0], cmap='gray')
# Out:
# (2048, 2048, 3)

# %%
plt.imshow(img[:,:,1], cmap='gray')

# %%
plt.imshow(img[:,:,2], cmap='gray')

# %%
img_copy = img.copy()
img_copy[ img_copy == 0] = 255
plt.imshow(img_copy, cmap='gray')
