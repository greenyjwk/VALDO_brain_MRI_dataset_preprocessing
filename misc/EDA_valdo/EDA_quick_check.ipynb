# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
mask_path = "/media/Datacenter_storage/Ji/BiomedParse/biomedparse_datasets/valdo_biomedparse/train_mask/sub-101-slice-027_MRI_Brain_cmb.png"
# mask_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/valdo_png/masks/train/sub-101_slice_016.png"

# %%
mask = Image.open(mask_path)
mask = np.array(mask)
print(mask.shape)
print(np.unique(mask))

zero_count = np.count_nonzero(mask[:,:] != 0)
print(zero_count)
# Out:
# (512, 512)
# [  0 255]
# 11

# %%
plt.imshow(mask[:,:,0], cmap='gray')
print(np.unique(mask[:,:,0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.imshow(mask[:,:,0], cmap='gray')
#       2 print(np.unique(mask[:,:,0]))
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
plt.imshow(mask[:,:,1], cmap='gray')
print(np.unique(mask[:,:,1]))
# Out:
# [  0 255]

# %%
plt.imshow(mask[:,:,2], cmap='gray')
print(np.unique(mask[:,:,2]))
# Out:
# [  0 255]
