# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
slice_num = 121
uid = "sub-217"

# %%
file_path_0 = f"/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/CSF_NIFTI/csf_segment_threshold_train/{uid}/T1_seg_0.nii.gz"
file_0 = nib.load(file_path_0)
img_0 = file_0.get_fdata()

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(img_0[:, :, slice_num], cmap='gray')
# plt.imshow(np.rot90(img_0[:, :, slice_num], k =1), cmap='gray')
