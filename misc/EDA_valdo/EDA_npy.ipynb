# %%
import os
import numpy as np
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# ### all sequence

# %%
npy_file = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO_3consecutive_npy_preprocessed/MRI_Brain_CMB/imgs/MRI_Brain_CMB_sub-305-001.npy"
arr = np.load(npy_file)
print(arr.shape)
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(arr[:,:,0], cmap= 'gray')
plt.subplot(1,3,2)
plt.imshow(arr[:,:,1], cmap= 'gray')
plt.subplot(1,3,3)
plt.imshow(arr[:,:,2], cmap= 'gray')
# Out:
# (1024, 1024, 3)

# %%
gt_file = npy_file.replace('imgs', 'gts')
arr = np.load(gt_file)
print(arr.shape)
plt.imshow(arr[:,:], cmap= 'gray')
# Out:
# (1024, 1024)
