# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
uid="106"
slice="014"
task = "train"
root_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/csf_png/"

image_path = f"{root_path}/images/{task}/sub-{uid}_slice_{slice}.png"
mask_path = f"{root_path}/masks/{task}/sub-{uid}_slice_{slice}.png"
image = Image.open(image_path)
mask = Image.open(mask_path)

image_data = np.array(image)
mask_data = np.array(mask)
# mask_data = np.rot90(mask_data, k=1)

print(np.unique(mask_data))
np.count_nonzero(mask_data == 255)
# Out:
# [0 2]
# 0

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.imshow(image_data[:,:], cmap='gray')

plt.subplot(1,2,2)
plt.imshow(mask_data, cmap='gray')

# %%
biomedparse_mask_file_path = "/media/Datacenter_storage/Ji/BiomedParse/biomedparse_datasets/valdo_biomedparse_csf/train_mask/sub-101-slice-017_MRI_Brain_csf.png"
file = Image.open(biomedparse_mask_file_path)
print(np.unique(np.array(file)))
# Out:
# [0 1]
