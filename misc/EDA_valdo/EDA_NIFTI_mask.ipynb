# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
mrn = "sub-101"
slice_num = 9
mask_root = "/mnt/storage/ji/csf_segment_train"

# %%
img_path0 = f"{mask_root}/{mrn}/T1_seg_0.nii.gz"

img = nib.load(img_path0)
header=img.header
# print(header['pixdim'])

img = img.get_fdata()
img = np.rot90(img, 1)
img = img.astype(np.uint8)

print(img.shape)
print(np.unique(img))

plt.imshow(img[:, :, slice_num], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /media/Datacenter_storage/Ji/HOME_MEDIA/miniconda3/envs/biomedparse_train/lib/python3.9/site-packages/nibabel/loadsave.py:101, in load(filename, **kwargs)
#     100 try:
# --> 101     stat_result = os.stat(filename)
#     102 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/storage/ji/csf_segment_train/sub-101/T1_seg_0.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 img_path0 = f"{mask_root}/{mrn}/T1_seg_0.nii.gz"
# ----> 3 img = nib.load(img_path0)
#       4 header=img.header
#       5 # print(header['pixdim'])
#
# File /media/Datacenter_storage/Ji/HOME_MEDIA/miniconda3/envs/biomedparse_train/lib/python3.9/site-packages/nibabel/loadsave.py:103, in load(filename, **kwargs)
#     101     stat_result = os.stat(filename)
#     102 except OSError:
# --> 103     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     104 if stat_result.st_size <= 0:
#     105     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: '/mnt/storage/ji/csf_segment_train/sub-101/T1_seg_0.nii.gz'

# %%
nifti_img = f"{root}/{mrn}/{mrn}_space-T2S_desc-masked_T2S.nii.gz"

nifti_img = nib.load(nifti_img)

nifti_img = nifti_img.get_fdata()
nifti_img = nifti_img[:,:,slice_num]
img = np.rot90(nifti_img, 1)
print(img.shape)

plt.imshow(img[:, :], cmap='gray')
# Out:
# (512, 512)

# %%
img_path1 = f"{root}/{mrn}/sub-P{mrn}_{mrn}.nii.gz"
img = nib.load(img_path1)
header=img.header
print(header['pixdim'])

img = img.get_fdata()
print(img.shape)

plt.imshow(img[:, :, slice], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/nibabel/loadsave.py:100, in load(filename, **kwargs)
#      99 try:
# --> 100     stat_result = os.stat(filename)
#     101 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction/sub-101/sub-Psub-101_sub-101.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 img_path1 = f"{root}/{mrn}/sub-P{mrn}_{mrn}.nii.gz"
# ----> 2 img = nib.load(img_path1)
#       3 header=img.header
#       4 print(header['pixdim'])
#
# File ~/miniconda3/envs/brainIMG/lib/python3.11/site-packages/nibabel/loadsave.py:102, in load(filename, **kwargs)
#     100     stat_result = os.stat(filename)
#     101 except OSError:
# --> 102     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     103 if stat_result.st_size <= 0:
#     104     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: '/mnt/storage/ji/brain_mri_valdo_mayo/valdo_resample_ALFA_bias_field_correction/sub-101/sub-Psub-101_sub-101.nii.gz'

# %%
img_path2 = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/SAG_3D_T2_SPACE_{mrn}.nii.gz"
img = nib.load(img_path2)
header=img.header
print(header['pixdim'])
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:, :, slice], cmap='gray')
# Out:
# [1.       0.859375 0.859375 4.       0.       1.       1.       1.      ]
# (256, 256, 44)

# %%
img_path3 = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/Axial_3TE_T2_STAR_{mrn}.nii.gz"
img = nib.load(img_path3)
header=img.header
print(header['pixdim'])
img = img.get_fdata()
print(img.shape)
plt.imshow(img[:, :, slice, 2], cmap='gray')
# Out:
# [-1.        0.859375  0.859375  4.        0.        1.        1.
#   1.      ]
# (256, 256, 44, 3)

# %%
import matplotlib.pyplot as plt
import nibabel as nib

# File paths for the three images
# img_path1 = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/Axial_3TE_T2_STAR_{mrn}_1.nii.gz"
# img_path2 = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/Axial_3TE_T2_STAR_{mrn}_2.nii.gz"
# img_path3 = f"/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/{sub_root}/{mrn}/Axial_3TE_T2_STAR_{mrn}_3.nii.gz"

# Load images
img0 = nib.load(img_path0).get_fdata()
img1 = nib.load(img_path1).get_fdata()
img2 = nib.load(img_path2).get_fdata()
img3 = nib.load(img_path3).get_fdata()

# Select a slice to display
# Create a figure with three subplots
plt.figure(figsize=(15, 5))

# Plot the first image
plt.subplot(1, 4, 1)
plt.imshow(img0[:, :, slice], cmap='gray')
plt.title("csf")
plt.axis('off')

# Plot the first image
plt.subplot(1, 4, 2)
plt.imshow(img1[:, :, slice], cmap='gray')
plt.title("T1")
plt.axis('off')

# Plot the second image
plt.subplot(1, 4, 3)
plt.imshow(img2[:, :, slice], cmap='gray')
plt.title("T2")
plt.axis('off')

# Plot the third image
plt.subplot(1, 4, 4)
plt.imshow(img3[:, :, slice, 2], cmap='gray')
plt.title("T2*")
plt.axis('off')

# Show the combined plot
plt.tight_layout()
plt.show()

# %%
img_path_0 = f"/media/Datacenter_storage/Ji/csf_segment/{mrn}/T1_seg_0.nii.gz"
img_0 = nib.load(img_path_0)
header=img_0.header
print(header['pixdim'])

img_0 = img_0.get_fdata()
print(img_0.shape)

img_path_1 = f"/media/Datacenter_storage/Ji/csf_segment/{mrn}/T1_seg_1.nii.gz"
img_1 = nib.load(img_path_1)
header=img_1.header
print(header['pixdim'])

img_1 = img_1.get_fdata()
print(img_1.shape)

plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.imshow(img_0[:, :, slice], cmap='gray')

plt.subplot(1,2,2)
plt.imshow(img_1[:, :, slice], cmap='gray')
# Out:
# [1.       0.859375 0.859375 4.       0.       0.       0.       0.      ]
# (256, 256, 44)
# [1.       0.859375 0.859375 4.       0.       0.       0.       0.      ]
# (256, 256, 44)

# %%
img_path = "/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/3ch_stacked/sub-207/sub-207.nii.gz"

img_file = nib.load(img_path)
img_file = img_file.get_fdata()
print(img_file.shape)

plt.subplot(1,3,1)
plt.imshow(img_file[:,:,103, 0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img_file[:,:,103, 1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img_file[:,:,103, 2], cmap='gray')
# Out:
# (512, 512, 192, 3)

# %%
mask_path = "/media/Datacenter_storage/Ji/csf_segment_threshold/4817777/T1_seg_0.nii.gz"

mask_file = nib.load(mask_path)
mask_file = mask_file.get_fdata()
print(mask_file.shape)
plt.imshow(mask_file[:,:,20])
# Out:
# (256, 256, 44)
