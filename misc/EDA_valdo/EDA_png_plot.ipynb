# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image

# %%
# img_path = os.path.join("/media/Datacenter_storage/Ji/valdo_dataset/valdo_resample_ALFA_YOLO_PNG_epd_gt_box_t2s_GAN_3slices_cmbTrainOnly/images/val/sub-110_slice_032.png")
img_path = "/media/Datacenter_storage/Ji/valdo_dataset/valdo_T1T2_cmbOnly_GAN/images/val/sub-103_slice_017.png"
img = Image.open(img_path)
img = np.array(img)

plt.figure(figsize=(10, 10))

plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

# plt.subplot(1,3,3)
# plt.imshow(img[:,:,2], cmap='gray')

# %%
# /media/Datacenter_storage/Ji/valdo_dataset/valdo_all_sequence_cmbOnly_GAN/images/val/sub-110_slice_030.png

# %%
img_path = os.path.join("/media/Datacenter_storage/Ji/valdo_dataset/valdo_all_sequence_cmbOnly_GAN/images/val/sub-110_slice_029.png")
img = Image.open(img_path)
img = np.array(img)

plt.figure(figsize=(10, 10))

plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
