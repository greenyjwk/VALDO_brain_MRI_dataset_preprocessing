# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image

# %%
img_path = os.path.join("/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/valdo_png/images/train/sub-305_slice_012.png")
# img_path = "/media/Datacenter_storage/Ji/valdo_dataset/valdo_T1T2_cmbOnly_GAN/images/val/sub-206_slice_085.png"
img = Image.open(img_path)
img = np.array(img)
print(img.shape)

plt.figure(figsize=(10, 10))

plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
plt.axis('off')
# Out:
# (512, 512, 3)
# (-0.5, 511.5, 511.5, -0.5)

# %%
img_path = os.path.join("/media/Datacenter_storage/PublicDatasets/cerebral_microbleeds_VALDO/valdo_png/images/train/sub-305_slice_012.png")
img = Image.open(img_path)
img = np.array(img)

plt.figure(figsize=(10, 10))

plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
