# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt

# %%
MRN = "4817777"
slice = 22

# %%
root = "/media/Datacenter_storage/Ji/brain_mri_valdo_mayo/mayo_skull_stripped"

T1 = nib.load(os.path.join(root, MRN, f"3D_SAG_T1_MPRAGE_1MM_{MRN}.nii.gz"))
T1 = T1.get_fdata()

T2 = nib.load(os.path.join(root, MRN, f"SAG_3D_T2_SPACE_{MRN}.nii.gz"))
T2 = T2.get_fdata()

T2S = nib.load(os.path.join(root, MRN, f"Axial_3TE_T2_STAR_{MRN}.nii.gz"))
T2S = T2S.get_fdata()

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.imshow(T1[:,:,slice].T, cmap='gray', origin='lower')
plt.title('T1')

plt.subplot(132)
plt.imshow(T2[:,:,slice].T, cmap='gray', origin='lower')
plt.title('T2')

plt.subplot(133)
plt.imshow(T2S[:,:,slice, 2].T, cmap='gray', origin='lower')
plt.title('T2S')
# Out:
# Text(0.5, 1.0, 'T2S')
