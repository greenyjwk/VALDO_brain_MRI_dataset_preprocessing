# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
temp_img = Image.open("/media/Datacenter_storage/Ji/valdo_dataset/valdo_T1T2_cmbOnly_GAN/images/train/sub-101_slice_011.png")
temp_img = np.array(temp_img)
plt.imshow(temp_img[:,:,0], cmap='gray')

# %%
temp_img = Image.open("/media/Datacenter_storage/Ji/valdo_dataset/valdo_all_sequence_cmbOnly_GAN/images/train/sub-221_slice_139.png")
temp_img = np.array(temp_img)
print(temp_img.shape)
plt.imshow(temp_img[:,:,1], cmap='gray')
# Out:
# (2048, 2048, 3)
