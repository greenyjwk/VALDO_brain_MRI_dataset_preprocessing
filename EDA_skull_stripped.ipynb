# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
T1 = nib.load("/mnt/storage/ji/VALDO_preprocessing/skull-stripped/sub-108/sub-108_space-T2S_desc-masked_T1.nii.gz")
T1 = T1.get_fdata()

T2 = nib.load("/mnt/storage/ji/VALDO_preprocessing/skull-stripped/sub-108/sub-108_space-T2S_desc-masked_T2.nii.gz")
T2 = T2.get_fdata()

T2S = nib.load("/mnt/storage/ji/VALDO_preprocessing/skull-stripped/sub-108/sub-108_space-T2S_desc-masked_T2S.nii.gz")
T2S = T2S.get_fdata()

# %%
depth = 20

plt.figure(figsize=(15,5))

plt.subplot(131)
plt.imshow(T1[:,:,depth].T, cmap='gray', origin='lower')
plt.title('T1')

plt.subplot(132)
plt.imshow(T2[:,:,depth].T, cmap='gray', origin='lower')
plt.title('T2')

plt.subplot(133)
plt.imshow(T2S[:,:,depth].T, cmap='gray', origin='lower')
plt.title('T2S')
# Out:
# Text(0.5, 1.0, 'T2S')
